# %%
import pandas, nltk, string, numpy, csv
from pattern.fr import parse, split
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import linalg
from sklearn.cluster import KMeans
import collections
from pprint import pprint

# %%
from langdetect import detect

# %%
bnp=pandas.read_csv('bnp.csv', encoding = 'utf-8').drop_duplicates()

# %%
bnp
# Out:
#                                         reviewHeadline  \
# 0                    environnement de travail agréable
# 1    Agréable quand on va dans le sens de la hiérar...
# 2                         Bon environnement de travail
# 3                           AMOA GED dematérialisation
# 4                                       stage agréable
# 5                                               emploi
# 6                    environnement de travail agréable
# 7               Expérience professionnel très agréable
# 8                              Bonne ambiance générale
# 9                                              cetelem
# 10                        Bon environnement de travail
# 11                   Environnement de travail agréable
# 12        bonne conivence entre l'équipe et le travail
# 13                  Environment parfait pour apprendre
# 14                            Environnement de Travail
# 15                            Travail très intéressant
# 16                                     Journée typique
# 17                                    Travail agreable
# 18                                            agreable
# 19   Travail motivant, belle autonomie et équipe so...
# 20    Proximité aupès de la clientèle des particuliers
# 22                   environnement de travail agréable
# 23                                          BTS Banque
# 24                                   Poussé au chiffre
# 25                   Bon accompagnement des alternants
# 26                  Stage au sein de BNP Paribas Cergy
# 27                                   Equipes agréables
# 28                                   Un rythme intense
# 29   Environnement de travail rigoureux, compétitif...
# 30                                     Esprit d'équipe
# ..                                                 ...
# 421                           Progressive Organization
# 422                                    A market leader
# 423                              Good business exposer
# 424     Nice place to work but too slow in advancement
# 425             Great benefits but lack of progression
# 426  Excellent company values, well managed, and st...
# 427                          The bank gives you a life
# 428                                               good
# 429        Very nice place to work and enviroment good
# 430                              Challenging workplace
# 431                      Equipe excelente de trabalhar
# 432                                        Loan Review
# 433                                      Fun workplace
# 434           De bank is een fijn bedrijf om te werken
# 435                                         Productive
# 436                     Als werkgever geen hoogvlieger
# 437               Good place, but average pay for work
# 438                        Business Continuity Project
# 439                                              Buena
# 440                            Learning and productive
# 442       Fast paced, intense but rewarding workplace.
# 443                                   Great management
# 444                               Productive workplace
# 445                                 nice place to work
# 446                            Very nice place to work
# 447                                  Excellent company
# 448  Good for resume experience, hard to advance wi...
# 449                    Not a good place for performers
# 450             Large International Bank culture in US
# 451                           Productive place to work
#
#                authorJobLocation  \
# 0                       Paris 10
# 1       Champigny-sur-Marne (94)
# 2               Paris, Montreuil
# 3                      Paris, A8
# 4            Rueil-Malmaison, A8
# 5             val d oise et oise
# 6              joinville le pont
# 7                      Montreuil
# 8                          Paris
# 9                      marseille
# 10                      Nanterre
# 11                         Eauze
# 12                 Marseille, B8
# 13           Issy Les Moulineaux
# 14                      Paris 9e
# 15               Saint-Denis, A8
# 16                         paris
# 17                         Paris
# 18                     Montreuil
# 19                  Nanterre, A8
# 20             La Valette du Var
# 22   3 rue d'Antin (75002 Paris)
# 23                        Nantes
# 24                     Paris SUD
# 25           Rueil-Malmaison, A8
# 26                Cergy Pontoise
# 27                   Mornant, B9
# 28                   L'Union, B3
# 29                     Marseille
# 30                     Paris, A8
# ..                           ...
# 421                 New York, NY
# 422              Jersey City, NJ
# 423                 New York, NY
# 424                 New York, NY
# 425            Scotland, Glasgow
# 426                       Sydney
# 427                 New York, NY
# 428                Manhattan, NY
# 429              Jersey City, NJ
# 430                São Paulo, SP
# 431                  Lisboa, P11
# 432                  New York NY
# 433                   IT Officer
# 434                       Leuven
# 435                      chennai
# 436                      Brussel
# 437                 New York, NY
# 438                       London
# 439                       Madrid
# 440                 Mumbai,India
# 442                New York City
# 443                 New York, NY
# 444                 New York, NY
# 445                     new york
# 446                 New York, NY
# 447                     New York
# 448                  Chicago, IL
# 449                  Jersey City
# 450                     New York
# 451           New York, New York
#
#                                      reviewDescription      company  \
# 0    poste intéressant avec beaucoup de formations....  BNP Paribas
# 1    il est agréable de travailler chez BNP Paribas...  BNP Paribas
# 2    J'y travaillais beaucoup, mais avec des person...  BNP Paribas
# 3    Equipe  sympa.,Ambiance correcte,Envoi de flux...  BNP Paribas
# 4    Stage d'été agréable, des premières missions a...  BNP Paribas
# 5    periode trop courte pour en juger.,Mais bonne ...  BNP Paribas
# 6    à l'agence de joinville le pont, l'environneme...  BNP Paribas
# 7    Ma journée consistait à effectuer une surveill...  BNP Paribas
# 8    Au sein de la BNP Paribas, j'ai eu la chance d...  BNP Paribas
# 9    Bonne entreprise,Très bonne ambiance au sein d...  BNP Paribas
# 10   Le poste que j'occupe actuellement est transve...  BNP Paribas
# 11   Journée de travail agréable en globalité.,Pers...  BNP Paribas
# 12   Développement et formation qui sont des opport...  BNP Paribas
# 13   -Rythme de travail soutenu et parfait pour le ...  BNP Paribas
# 14   Excellente relation entre les différents servi...  BNP Paribas
# 15   Préparation de la journée, préparer son poste ...  BNP Paribas
# 16   Je suis très satisfait des journées de travail...  BNP Paribas
# 17   Analysis and writing of macroscopic impact stu...  BNP Paribas
# 18   Les collègues sont gentils.,Travail pas dur,j'...  BNP Paribas
# 19   La charge de travail était importante mais j'a...  BNP Paribas
# 20   J'étais en contrat de professionnalisation, en...  BNP Paribas
# 22   grosse société avec ses avantages et ses incon...  BNP Paribas
# 23   Peu de conseil, beaucoup de commercial. ,Bonne...  BNP Paribas
# 24   Normal car à la rentrée scolaire, période effe...  BNP Paribas
# 25   Chez BNP Paribas Cardif nous pouvons mettre en...  BNP Paribas
# 26   J'ai effectué un stage de 3 mois au sein de la...  BNP Paribas
# 27   Prise en considération des salariés. Bonne coh...  BNP Paribas
# 28   Une journée de travail se compose par un morni...  BNP Paribas
# 29   Chargé d'Administration du Crédit est un poste...  BNP Paribas
# 30   Convivialité et très bon esprit d'équipe au se...  BNP Paribas
# ..                                                 ...          ...
# 421   Performed credit reviews of selected counter...  BNP Paribas
# 422  The hardest part of my job is finding new ways...  BNP Paribas
# 423  Friendly business environment, good learning e...  BNP Paribas
# 424  Nice place to work, Good work/life balance,Lac...  BNP Paribas
# 425  The company could improve it's routes of progr...  BNP Paribas
# 426  BNP Paribas is an excellent global financial s...  BNP Paribas
# 427  Typical working hours with lots of vacations.,...  BNP Paribas
# 428  good place to work! BNP is a company you will ...  BNP Paribas
# 429  review all incoming and outgoing payments maki...  BNP Paribas
# 430  Work in BNP Paribas software department is a g...  BNP Paribas
# 431  Rever as rotinas da noite anteriort,A der mais...  BNP Paribas
# 432   Performed credit reviews of selected counter...  BNP Paribas
# 433  BNP Paribas is a International Bank, Head offi...  BNP Paribas
# 434  Functie als commercieel adviseur bij BNP Parib...  BNP Paribas
# 435  We got an opportunity to go to Sydney to migra...  BNP Paribas
# 436  Elke dag maak je zelf. Je gaat om met stress i...  BNP Paribas
# 437  Great atmosphere, very collaborative and helpf...  BNP Paribas
# 438  Developed project management skills. Working w...  BNP Paribas
# 439  Empresa del sector financierocon un buen equip...  BNP Paribas
# 440  Learnt new technologies.,Enjoyed the Process a...  BNP Paribas
# 442  A typical day at work involved arriving at my ...  BNP Paribas
# 443  Great management,Wonderful work environment,Fa...  BNP Paribas
# 444  Productive workplace,long hours, smart people....  BNP Paribas
# 445  managers and clerks were fun to work with.bene...  BNP Paribas
# 446  As the Administrative Assistant to 4 Managing ...  BNP Paribas
# 447  Busy, very corporate, but friendly environment...  BNP Paribas
# 448  Great international exposure but limited advan...  BNP Paribas
# 449  Nepotism, useless management, and slow. No val...  BNP Paribas
# 450  HR / Benefits very good- from the orientation ...  BNP Paribas
# 451  Management was there to help when needed. Work...  BNP Paribas
#
#      compensationAndBenefitsRating  \
# 0                                0
# 1                                4
# 2                                0
# 3                                4
# 4                                0
# 5                                2
# 6                                3
# 7                                4
# 8                                5
# 9                                0
# 10                               4
# 11                               4
# 12                               4
# 13                               5
# 14                               5
# 15                               0
# 16                               4
# 17                               0
# 18                               5
# 19                               4
# 20                               4
# 22                               2
# 23                               5
# 24                               5
# 25                               0
# 26                               4
# 27                               5
# 28                               3
# 29                               5
# 30                               0
# ..                             ...
# 421                              5
# 422                              4
# 423                              4
# 424                              3
# 425                              3
# 426                              5
# 427                              4
# 428                              5
# 429                              5
# 430                              4
# 431                              4
# 432                              5
# 433                              3
# 434                              4
# 435                              4
# 436                              3
# 437                              3
# 438                              4
# 439                              3
# 440                              5
# 442                              5
# 443                              5
# 444                              4
# 445                              3
# 446                              1
# 447                              5
# 448                              3
# 449                              3
# 450                              4
# 451                              0
#
#                                              authorJob  \
# 0    Gestionnaire Crédits Structurés (Ancien employ...
# 1              Conseiller clientèle (Ancien employé),
# 2                        Consultant (Ancien employé),
# 3    Consultant AMOA GED-Dématérialisation (Employé...
# 4                  Auxiliaire d'été (Ancien employé),
# 5                 accueil clientele (Ancien employé),
# 6              Gestion de l'accueil (Ancien employé),
# 7         Technicien D'exploitation (Ancien employé),
# 8        Gestionnaire Administratif (Ancien employé),
# 9            Auxiliaire de vacances (Ancien employé),
# 10    Contrôleur Financier (Senior) (Ancien employé),
# 11                Hôtesse d'accueil (Ancien employé),
# 12   Gestion décompte - remboursement anticipé (Emp...
# 13   Financial Analyst (Internship) (Ancien employé),
# 14   Chargé de Portefeuille Immobilier (Ancien empl...
# 15             Conseiller clientèle (Ancien employé),
# 16   Analyste de performance de Portefeuille OPCVM ...
# 17                          Analyst (Ancien employé),
# 18                            Stage (Ancien employé),
# 19   Juriste en assurance, distribution et corporat...
# 20   Chargée de Clientèle des Particuliers (Ancien ...
# 22   assistante Directeur de la Communication Group...
# 23   Conseiller clientèle et accueil (Ancien employ...
# 24   Commercial " Jeune " BNP Paribas (Ancien emplo...
# 25   Alternance rédacteur successions (Ancien emplo...
# 26   Stage en Animation Commerciale (Ancien employé),
# 27   CHARGÉE DE CLIENTÈLE EN ALTERNANCE (Ancien emp...
# 28           CONSEILLER PATRIMONIAL (Employé actuel),
# 29   Apprenti Chargé d'administration du crédit (An...
# 30          Stage Juridique, 6 mois (Ancien employé),
# ..                                                 ...
# 421  VICE PRESIDENT, Audit - Financing Activities (...
# 422                      Oracle DBA (Employé actuel),
# 423                         Analyst (Ancien employé),
# 424           Senior Credit Analyst (Employé actuel),
# 425             Trade administartor (Ancien employé),
# 426           Chief Audit Executive (Employé actuel),
# 427  Prime Brokerage Risk Analyst (Part-time) (Empl...
# 428      CMS Designer and developer (Employé actuel),
# 429             Payments Specialist (Ancien employé),
# 430  System Analyst & Java Developer Senior (Employ...
# 431            Analista de sistemas (Ancien employé),
# 432                  Vice President (Ancien employé),
# 433                      IT Officer (Employé actuel),
# 434            commercieel adviseur (Ancien employé),
# 435                    Sr.Associate (Employé actuel),
# 436   Senior Buyer / Project Leader (Ancien employé),
# 437  Sales & Trading Associate Intern (Ancien emplo...
# 438                 Project Manager (Employé actuel),
# 439     Senior Relationship Manager (Ancien employé),
# 440       IT security Administrator (Ancien employé),
# 442                  Vice President (Ancien employé),
# 443  Derivatives Documentation Analyst (Employé act...
# 444  AVP/CASH MANAGEMENT/ PORTFOLIO ADMINISTRATOR (...
# 445     Securities Senior Associate (Ancien employé),
# 446  Administrative Assistant to 4 Managing Directo...
# 447             Executive Assistant (Ancien employé),
# 448         Portfolio Administrator (Employé actuel),
# 449      Senior Technical Architect (Employé actuel),
# 450                        Director (Ancien employé),
# 451        Assistant Vice Predident (Ancien employé),
#
#      cultureAndValuesRating  workLifeBalanceRating  careerOpportunitiesRating  \
# 0                         0                      0                          0
# 1                         2                      4                          4
# 2                         0                      0                          0
# 3                         1                      4                          1
# 4                         0                      0                          0
# 5                         2                      2                          2
# 6                         3                      4                          2
# 7                         5                      4                          4
# 8                         4                      4                          4
# 9                         0                      0                          0
# 10                        4                      4                          3
# 11                        4                      4                          4
# 12                        4                      4                          4
# 13                        4                      5                          5
# 14                        5                      5                          5
# 15                        0                      0                          0
# 16                        4                      5                          3
# 17                        0                      0                          0
# 18                        5                      5                          5
# 19                        4                      3                          3
# 20                        3                      3                          4
# 22                        3                      3                          2
# 23                        4                      2                          4
# 24                        5                      5                          3
# 25                        0                      0                          0
# 26                        5                      4                          4
# 27                        4                      4                          3
# 28                        4                      2                          4
# 29                        5                      5                          5
# 30                        5                      5                          3
# ..                      ...                    ...                        ...
# 421                       5                      5                          4
# 422                       3                      3                          2
# 423                       4                      4                          4
# 424                       3                      4                          3
# 425                       3                      4                          2
# 426                       5                      4                          4
# 427                       5                      5                          4
# 428                       5                      5                          5
# 429                       5                      5                          3
# 430                       5                      5                          5
# 431                       4                      5                          3
# 432                       5                      5                          5
# 433                       3                      3                          2
# 434                       5                      3                          5
# 435                       2                      3                          3
# 436                       3                      3                          3
# 437                       0                      0                          0
# 438                       5                      4                          3
# 439                       3                      3                          3
# 440                       0                      0                          0
# 442                       5                      4                          2
# 443                       5                      5                          5
# 444                       2                      3                          2
# 445                       3                      3                          3
# 446                       4                      4                          1
# 447                       5                      5                          5
# 448                       3                      4                          2
# 449                       2                      2                          4
# 450                       2                      2                          2
# 451                       0                      3                          0
#
#      seniorLeadershipRating         reviewDate
# 0                         0     6 juillet 2015
# 1                         2   25 novembre 2015
# 2                         0   24 novembre 2015
# 3                         1   21 novembre 2015
# 4                         0    3 novembre 2015
# 5                         2    24 octobre 2015
# 6                         3    16 octobre 2015
# 7                         5     7 octobre 2015
# 8                         4     6 octobre 2015
# 9                         0     5 octobre 2015
# 10                        4  29 septembre 2015
# 11                        4  29 septembre 2015
# 12                        4  26 septembre 2015
# 13                        5  23 septembre 2015
# 14                        5  21 septembre 2015
# 15                        0  18 septembre 2015
# 16                        4  15 septembre 2015
# 17                        0  14 septembre 2015
# 18                        5   9 septembre 2015
# 19                        4   3 septembre 2015
# 20                        2       27 août 2015
# 22                        2       19 août 2015
# 23                        4        7 août 2015
# 24                        5        6 août 2015
# 25                        0        4 août 2015
# 26                        4        4 août 2015
# 27                        5    30 juillet 2015
# 28                        3    27 juillet 2015
# 29                        4    25 juillet 2015
# 30                        5    21 juillet 2015
# ..                      ...                ...
# 421                       5    4 novembre 2012
# 422                       3    28 octobre 2012
# 423                       4    22 octobre 2012
# 424                       3    14 octobre 2012
# 425                       1    13 octobre 2012
# 426                       5    12 octobre 2012
# 427                       4    12 octobre 2012
# 428                       5     5 octobre 2012
# 429                       5  24 septembre 2012
# 430                       5  15 septembre 2012
# 431                       5  13 septembre 2012
# 432                       5   4 septembre 2012
# 433                       3       25 août 2012
# 434                       4    19 juillet 2012
# 435                       2     4 juillet 2012
# 436                       3       12 juin 2012
# 437                       0        3 juin 2012
# 438                       4        1 juin 2012
# 439                       3        24 mai 2012
# 440                       0        19 mai 2012
# 442                       3         8 mai 2012
# 443                       5         1 mai 2012
# 444                       3      26 avril 2012
# 445                       3      19 avril 2012
# 446                       4       6 avril 2012
# 447                       5       30 mars 2012
# 448                       3       19 mars 2012
# 449                       1       15 mars 2012
# 450                       2       13 mars 2012
# 451                       4        9 mars 2012
#
# [431 rows x 11 columns]

# %%
bnp1=bnp[['reviewDescription','authorJobLocation','authorJob','reviewDate']]

# %%
bnp1
# Out:
#                                      reviewDescription  \
# 0    poste intéressant avec beaucoup de formations....
# 1    il est agréable de travailler chez BNP Paribas...
# 2    J'y travaillais beaucoup, mais avec des person...
# 3    Equipe  sympa.,Ambiance correcte,Envoi de flux...
# 4    Stage d'été agréable, des premières missions a...
# 5    periode trop courte pour en juger.,Mais bonne ...
# 6    à l'agence de joinville le pont, l'environneme...
# 7    Ma journée consistait à effectuer une surveill...
# 8    Au sein de la BNP Paribas, j'ai eu la chance d...
# 9    Bonne entreprise,Très bonne ambiance au sein d...
# 10   Le poste que j'occupe actuellement est transve...
# 11   Journée de travail agréable en globalité.,Pers...
# 12   Développement et formation qui sont des opport...
# 13   -Rythme de travail soutenu et parfait pour le ...
# 14   Excellente relation entre les différents servi...
# 15   Préparation de la journée, préparer son poste ...
# 16   Je suis très satisfait des journées de travail...
# 17   Analysis and writing of macroscopic impact stu...
# 18   Les collègues sont gentils.,Travail pas dur,j'...
# 19   La charge de travail était importante mais j'a...
# 20   J'étais en contrat de professionnalisation, en...
# 22   grosse société avec ses avantages et ses incon...
# 23   Peu de conseil, beaucoup de commercial. ,Bonne...
# 24   Normal car à la rentrée scolaire, période effe...
# 25   Chez BNP Paribas Cardif nous pouvons mettre en...
# 26   J'ai effectué un stage de 3 mois au sein de la...
# 27   Prise en considération des salariés. Bonne coh...
# 28   Une journée de travail se compose par un morni...
# 29   Chargé d'Administration du Crédit est un poste...
# 30   Convivialité et très bon esprit d'équipe au se...
# ..                                                 ...
# 421   Performed credit reviews of selected counter...
# 422  The hardest part of my job is finding new ways...
# 423  Friendly business environment, good learning e...
# 424  Nice place to work, Good work/life balance,Lac...
# 425  The company could improve it's routes of progr...
# 426  BNP Paribas is an excellent global financial s...
# 427  Typical working hours with lots of vacations.,...
# 428  good place to work! BNP is a company you will ...
# 429  review all incoming and outgoing payments maki...
# 430  Work in BNP Paribas software department is a g...
# 431  Rever as rotinas da noite anteriort,A der mais...
# 432   Performed credit reviews of selected counter...
# 433  BNP Paribas is a International Bank, Head offi...
# 434  Functie als commercieel adviseur bij BNP Parib...
# 435  We got an opportunity to go to Sydney to migra...
# 436  Elke dag maak je zelf. Je gaat om met stress i...
# 437  Great atmosphere, very collaborative and helpf...
# 438  Developed project management skills. Working w...
# 439  Empresa del sector financierocon un buen equip...
# 440  Learnt new technologies.,Enjoyed the Process a...
# 442  A typical day at work involved arriving at my ...
# 443  Great management,Wonderful work environment,Fa...
# 444  Productive workplace,long hours, smart people....
# 445  managers and clerks were fun to work with.bene...
# 446  As the Administrative Assistant to 4 Managing ...
# 447  Busy, very corporate, but friendly environment...
# 448  Great international exposure but limited advan...
# 449  Nepotism, useless management, and slow. No val...
# 450  HR / Benefits very good- from the orientation ...
# 451  Management was there to help when needed. Work...
#
#                authorJobLocation  \
# 0                       Paris 10
# 1       Champigny-sur-Marne (94)
# 2               Paris, Montreuil
# 3                      Paris, A8
# 4            Rueil-Malmaison, A8
# 5             val d oise et oise
# 6              joinville le pont
# 7                      Montreuil
# 8                          Paris
# 9                      marseille
# 10                      Nanterre
# 11                         Eauze
# 12                 Marseille, B8
# 13           Issy Les Moulineaux
# 14                      Paris 9e
# 15               Saint-Denis, A8
# 16                         paris
# 17                         Paris
# 18                     Montreuil
# 19                  Nanterre, A8
# 20             La Valette du Var
# 22   3 rue d'Antin (75002 Paris)
# 23                        Nantes
# 24                     Paris SUD
# 25           Rueil-Malmaison, A8
# 26                Cergy Pontoise
# 27                   Mornant, B9
# 28                   L'Union, B3
# 29                     Marseille
# 30                     Paris, A8
# ..                           ...
# 421                 New York, NY
# 422              Jersey City, NJ
# 423                 New York, NY
# 424                 New York, NY
# 425            Scotland, Glasgow
# 426                       Sydney
# 427                 New York, NY
# 428                Manhattan, NY
# 429              Jersey City, NJ
# 430                São Paulo, SP
# 431                  Lisboa, P11
# 432                  New York NY
# 433                   IT Officer
# 434                       Leuven
# 435                      chennai
# 436                      Brussel
# 437                 New York, NY
# 438                       London
# 439                       Madrid
# 440                 Mumbai,India
# 442                New York City
# 443                 New York, NY
# 444                 New York, NY
# 445                     new york
# 446                 New York, NY
# 447                     New York
# 448                  Chicago, IL
# 449                  Jersey City
# 450                     New York
# 451           New York, New York
#
#                                              authorJob         reviewDate
# 0    Gestionnaire Crédits Structurés (Ancien employ...     6 juillet 2015
# 1              Conseiller clientèle (Ancien employé),    25 novembre 2015
# 2                        Consultant (Ancien employé),    24 novembre 2015
# 3    Consultant AMOA GED-Dématérialisation (Employé...   21 novembre 2015
# 4                  Auxiliaire d'été (Ancien employé),     3 novembre 2015
# 5                 accueil clientele (Ancien employé),     24 octobre 2015
# 6              Gestion de l'accueil (Ancien employé),     16 octobre 2015
# 7         Technicien D'exploitation (Ancien employé),      7 octobre 2015
# 8        Gestionnaire Administratif (Ancien employé),      6 octobre 2015
# 9            Auxiliaire de vacances (Ancien employé),      5 octobre 2015
# 10    Contrôleur Financier (Senior) (Ancien employé),   29 septembre 2015
# 11                Hôtesse d'accueil (Ancien employé),   29 septembre 2015
# 12   Gestion décompte - remboursement anticipé (Emp...  26 septembre 2015
# 13   Financial Analyst (Internship) (Ancien employé),   23 septembre 2015
# 14   Chargé de Portefeuille Immobilier (Ancien empl...  21 septembre 2015
# 15             Conseiller clientèle (Ancien employé),   18 septembre 2015
# 16   Analyste de performance de Portefeuille OPCVM ...  15 septembre 2015
# 17                          Analyst (Ancien employé),   14 septembre 2015
# 18                            Stage (Ancien employé),    9 septembre 2015
# 19   Juriste en assurance, distribution et corporat...   3 septembre 2015
# 20   Chargée de Clientèle des Particuliers (Ancien ...       27 août 2015
# 22   assistante Directeur de la Communication Group...       19 août 2015
# 23   Conseiller clientèle et accueil (Ancien employ...        7 août 2015
# 24   Commercial " Jeune " BNP Paribas (Ancien emplo...        6 août 2015
# 25   Alternance rédacteur successions (Ancien emplo...        4 août 2015
# 26   Stage en Animation Commerciale (Ancien employé),         4 août 2015
# 27   CHARGÉE DE CLIENTÈLE EN ALTERNANCE (Ancien emp...    30 juillet 2015
# 28           CONSEILLER PATRIMONIAL (Employé actuel),     27 juillet 2015
# 29   Apprenti Chargé d'administration du crédit (An...    25 juillet 2015
# 30          Stage Juridique, 6 mois (Ancien employé),     21 juillet 2015
# ..                                                 ...                ...
# 421  VICE PRESIDENT, Audit - Financing Activities (...    4 novembre 2012
# 422                      Oracle DBA (Employé actuel),     28 octobre 2012
# 423                         Analyst (Ancien employé),     22 octobre 2012
# 424           Senior Credit Analyst (Employé actuel),     14 octobre 2012
# 425             Trade administartor (Ancien employé),     13 octobre 2012
# 426           Chief Audit Executive (Employé actuel),     12 octobre 2012
# 427  Prime Brokerage Risk Analyst (Part-time) (Empl...    12 octobre 2012
# 428      CMS Designer and developer (Employé actuel),      5 octobre 2012
# 429             Payments Specialist (Ancien employé),   24 septembre 2012
# 430  System Analyst & Java Developer Senior (Employ...  15 septembre 2012
# 431            Analista de sistemas (Ancien employé),   13 septembre 2012
# 432                  Vice President (Ancien employé),    4 septembre 2012
# 433                      IT Officer (Employé actuel),        25 août 2012
# 434            commercieel adviseur (Ancien employé),     19 juillet 2012
# 435                    Sr.Associate (Employé actuel),      4 juillet 2012
# 436   Senior Buyer / Project Leader (Ancien employé),        12 juin 2012
# 437  Sales & Trading Associate Intern (Ancien emplo...        3 juin 2012
# 438                 Project Manager (Employé actuel),         1 juin 2012
# 439     Senior Relationship Manager (Ancien employé),         24 mai 2012
# 440       IT security Administrator (Ancien employé),         19 mai 2012
# 442                  Vice President (Ancien employé),          8 mai 2012
# 443  Derivatives Documentation Analyst (Employé act...         1 mai 2012
# 444  AVP/CASH MANAGEMENT/ PORTFOLIO ADMINISTRATOR (...      26 avril 2012
# 445     Securities Senior Associate (Ancien employé),       19 avril 2012
# 446  Administrative Assistant to 4 Managing Directo...       6 avril 2012
# 447             Executive Assistant (Ancien employé),        30 mars 2012
# 448         Portfolio Administrator (Employé actuel),        19 mars 2012
# 449      Senior Technical Architect (Employé actuel),        15 mars 2012
# 450                        Director (Ancien employé),        13 mars 2012
# 451        Assistant Vice Predident (Ancien employé),         9 mars 2012
#
# [431 rows x 4 columns]

# %%
bnp1['language'] = (bnp1['reviewDescription']).apply(lambda x: detect(x))
# Out:
# /anaconda/envs/Python2.7/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
bnp1['OriginalReview'] = bnp1['reviewDescription']
# Out:
# /anaconda/envs/Python2.7/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
bnp_fr=bnp1[bnp1['language']=='fr']

# %%
bnp_fr.loc[:,'review_lower'] = bnp_fr['reviewDescription'].apply(lambda x: x.lower()).str.replace(',', ' ')
# Out:
# //anaconda/envs/Python2.7/lib/python2.7/site-packages/pandas/core/indexing.py:508: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
bnp_fr['review_tokens'] = bnp_fr['review_lower'].apply(lambda x: parse(x.replace('.',""), chunks = False, lemmata = True).split()[0])
# Out:
# /anaconda/envs/Python2.7/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
bnp_fr['review_tokens']
# Out:
# 0      [[poste, NN, poste], [intéressant, VBG, intére...
# 1      [[il, PRP, il], [est, VB, être], [agréable, JJ...
# 2      [[j', PRP, je], [y, PRP, y], [travaillais, VB,...
# 3      [[equipe, NN, equipe], [sympa, JJ, sympa], [am...
# 4      [[stage, NN, stage], [d', IN, de], [été, NN, é...
# 5      [[periode, NN, periode], [trop, RB, trop], [co...
# 6      [[à, IN, à], [l', DT, le], [agence, NN, agence...
# 7      [[ma, PRP$, mum], [journée, NN, journée], [con...
# 8      [[au, IN, au], [sein, NN, sein], [de, IN, de],...
# 9      [[bonne, JJ, bon], [entreprise, NN, entreprise...
# 10     [[le, DT, le], [poste, NN, poste], [que, IN, q...
# 11     [[journée, NN, journée], [de, IN, de], [travai...
# 12     [[développement, NN, développement], [et, CC, ...
# 13     [[-, -, -], [rythme, NN, rythme], [de, IN, de]...
# 14     [[excellente, JJ, excellent], [relation, NN, r...
# 15     [[préparation, NN, préparation], [de, IN, de],...
# 16     [[je, PRP, je], [suis, VB, suivre], [très, RB,...
# 18     [[les, DT, le], [collègues, NNS, collègue], [s...
# 19     [[la, DT, la], [charge, NN, charge], [de, IN, ...
# 20     [[j', PRP, je], [étais, VB, être], [en, IN, en...
# 22     [[grosse, JJ, grosse], [société, NN, société],...
# 23     [[peu, RB, peu], [de, IN, de], [conseil, NN, c...
# 24     [[normal, JJ, normal], [car, CC, car], [à, IN,...
# 25     [[chez, IN, chez], [bnp, NN, bnp], [paribas, N...
# 26     [[j', PRP, je], [ai, VB, avoir], [effectué, VB...
# 27     [[prise, VBN, priser], [en, IN, en], [considér...
# 28     [[une, DT, une], [journée, NN, journée], [de, ...
# 29     [[chargé, VBN, charger], [d', IN, de], [admini...
# 30     [[convivialité, NN, convivialité], [et, CC, et...
# 31     [[journée, NN, journée], [de, IN, de], [travai...
#                              ...
# 155    [[belle, JJ, bel], [expérience, NN, expérience...
# 156    [[l', DT, le], [équipe, NN, équipe], [corporat...
# 157    [[les, DT, le], [horaires, NNS, horaire], [éta...
# 158    [[équipe, NN, équipe], [agréable, JJ, agréable...
# 159    [[le, DT, le], [cadre, NN, cadre], [de, IN, de...
# 160    [[bon, JJ, bon], [employeur, NN, employeur], [...
# 161    [[entreprise, NN, entreprise], [qui, WP, qui],...
# 162    [[la, DT, la], [négociation, NN, négociation],...
# 163    [[entreprise, NN, entreprise], [professionnell...
# 164    [[mon, PRP$, mon], [expérience, NN, expérience...
# 165    [[soyez, VB, être], [plus, RB, plus], [ouverts...
# 166    [[bonne, JJ, bon], [expérience, NN, expérience...
# 167    [[les, DT, le], [opportunités, NNS, opportunit...
# 169    [[mon, PRP$, mon], [travail, NN, travail], [ét...
# 170    [[exécution, NN, exécution], [des, IN, des], [...
# 171    [[j', PRP, je], [ai, VB, avoir], [travaillé, V...
# 172    [[organisation, NN, organisation], [en, IN, en...
# 173    [[bonne, JJ, bon], [gestion, NN, gestion], [du...
# 174    [[-, -, -], [salaire, NN, salaire], [correct, ...
# 175    [[environnement, RB, environnement], [agréable...
# 176    [[entreprise, NN, entreprise], [dynamique, JJ,...
# 177    [[en, IN, en], [tant, RB, tant], [qu', IN, que...
# 178    [[dans, IN, dans], [des, IN, des], [locaux, JJ...
# 179    [[je, PRP, je], [travaille, VB, travailler], [...
# 180    [[en, IN, en], [tant, RB, tant], [que, IN, que...
# 181    [[le, DT, le], [travail, NN, travail], [est, V...
# 182    [[environnement, RB, environnement], [de, IN, ...
# 183    [[le, DT, le], [travail, NN, travail], [en, IN...
# 184    [[niveau, NN, niveau], [horaire, JJ, horaire],...
# 185    [[-, -, -], [des, IN, des], [journées, NNS, jo...
# Name: review_tokens, dtype: object

# %%
bnp_fr['review_lemmas'] =\
bnp_fr['review_tokens'].apply(lambda x: [t[2] for t in x if t[1] not in ['DT',\
'CC','IV','IN','PRP','PRP$','SYM','UH',',','.',':','(',')','-'] ])
# Out:
# /anaconda/envs/Python2.7/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
bnp_fr['review_lemmas']=bnp_fr['review_lemmas'].apply(lambda x: [t for t in x if t not in stopwords.words('french')])
# Out:
# /anaconda/envs/Python2.7/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
bnp_fr['review'] = bnp_fr['review_lemmas'].apply(lambda x: " ".join(x))
# Out:
# /anaconda/envs/Python2.7/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
bnp_fr['review']
# Out:
# 0      poste intéresser beaucoup formation bon entent...
# 1      être agréable travailler bnp pariba projet per...
# 2                   travailler beaucoup person compétent
# 3      equipe sympa ambiance correcte envoi flux xml ...
# 4      stage agréable premier mission adaptéer niveau...
# 5      periode trop courte juger bon experience bon r...
# 6      agence joinville pont environnement travail êt...
# 7      journée consister effectuer surveillance compt...
# 8      sein bnp pariba avoir avoir chance être tutell...
# 9       bon entreprise très bon ambiance sein entreprise
# 10     poste occuper actuellement être transversal tâ...
# 11     journée travail agréable globalité personnel s...
# 12     développement formation être opportunité évolu...
# 13     rythme travail soutenir parfait développement ...
# 14     excellent relation différent service différent...
# 15     préparation journée préparer poste travail occ...
# 16     suivre très satisfaire journée travail bnp pariba
# 18     collègue être gentil travail dur avoir amélior...
# 19     charge travail être important avoir énormément...
# 20     être contrat professionnalisation alternance g...
# 22     grosse société avantages inconvénient avoir tr...
# 23     peu conseil beaucoup commercial bon première e...
# 24     normal rentrée scolaire période effectif trava...
# 25     bnp pariba cardif pouvoir mettre bon accompagn...
# 26     avoir effectuer stage 3 mois sein succursale b...
# 27      priser considération salarié bon cohésion équipe
# 28     journée travail composer morning brief gestion...
# 29     charger administration crédit être poste trait...
# 30     convivialité très bon esprit équipe sein servi...
# 31     journée travail toujours très satisfaisant emp...
#                              ...
# 155    bel expérience professionnel travailler intére...
# 156    équipe corporate finance bnp pariba être très ...
# 157    horaire être assez flexible taches demandéer ê...
# 158    équipe agréable travail varier environnement a...
# 159    cadre travail être agréable collègue être mont...
# 160    bon employeur général banque français très hié...
# 161    entreprise permettre développer compétence acq...
# 162    négociation téléphonique fr régularisation éch...
# 163    entreprise professionnel international connais...
# 164    expérience sein bnp pariba qualité juriste fin...
# 165    être plus ouvertre jeun candidat manquer exper...
# 166    bon expérience évolution possible sein entrepr...
# 167    opportunité nombreux cdd bon structure travail...
# 169         travail être simple prendre énormément temps
# 170    exécution ordre clients gestion compte suivre ...
# 171    avoir travailler bnp pariba sourire tous jour ...
# 172    organisation plein changement situation très c...
# 173    bon gestion département ' corporate building '...
# 174    salaire correct horaire correct chèque repas c...
# 175    environnement agréable très bon convivialité t...
# 176    entreprise dynamique pouvoir encore plus dével...
# 177    tant employé banque avoir plein possibilité év...
# 178    local parfaitement entretenure bnp pariba genè...
# 179    travailler principalement monde immobilier ; s...
# 180    tant contrôleur gestion contrôleur financier e...
# 181    travail être trop diviser être maillon très gr...
# 182    environnement travail agréable poste intéresse...
# 183    travail agence pouvoir être aussi agréable div...
# 184    niveau horaire rien redire donner possibilité ...
# 185    journée travail intense forte pression commerc...
# Name: review, dtype: object

# %%
bnp_fr['review_lemmas']
# Out:
# 0      [poste, intéresser, beaucoup, formation, bon, ...
# 1      [être, agréable, travailler, bnp, pariba, proj...
# 2              [travailler, beaucoup, person, compétent]
# 3      [equipe, sympa,ambiance, correcte,envoi, flux,...
# 4      [stage, agréable, premier, mission, adaptéer, ...
# 5      [periode, trop, courte, juger,mai, bon, experi...
# 6      [agence, joinville, pont, environnement, trava...
# 7      [journée, consister, effectuer, surveillance, ...
# 8      [sein, bnp, pariba, avoir, avoir, chance, être...
# 9      [bon, entreprise,trè, bon, ambiance, sein, ent...
# 10     [poste, occuper, actuellement, être, transvers...
# 11     [journée, travail, agréable, globalité,personn...
# 12     [développement, formation, être, opportunité, ...
# 13     [rythme, travail, soutenir, parfait, développe...
# 14     [excellent, relation, différent, service, diff...
# 15     [préparation, journée, préparer, poste, travai...
# 16     [suivre, très, satisfaire, journée, travail, b...
# 18     [collègue, être, gentils,travail, dur,j, ', av...
# 19     [charge, travail, être, important, avoir, énor...
# 20     [être, contrat, professionnalisation, alternan...
# 22     [grosse, société, avantages, inconvénient, avo...
# 23     [peu, conseil, beaucoup, commercial, bonne, pr...
# 24     [normal, rentrée, scolaire, période, effectif,...
# 25     [bnp, pariba, cardif, pouvoir, mettre, bon, ac...
# 26     [avoir, effectuer, stage, 3, mois, sein, succu...
# 27     [priser, considération, salarié, bon, cohésion...
# 28     [journée, travail, composer, morning, brief, g...
# 29     [charger, administration, crédit, être, poste,...
# 30     [convivialité, très, bon, esprit, équipe, sein...
# 31     [journée, travail, toujours, très, satisfaisan...
#                              ...
# 155    [bel, expérience, professionnelle,travaille, i...
# 156    [équipe, corporate, finance, bnp, pariba, être...
# 157    [horaire, être, assez, flexible, taches, deman...
# 158    [équipe, agréable,travail, varié,environnement...
# 159    [cadre, travail, être, agréable, collègue, êtr...
# 160    [bon, employeur, générale,banque, français, tr...
# 161    [entreprise, permettre, développer, compétence...
# 162    [négociation, téléphonique, fr, régularisation...
# 163    [entreprise, professionnel, international, con...
# 164    [expérience, sein, bnp, pariba, qualité, juris...
# 165    [être, plus, ouvertre, jeun, candidat, manquer...
# 166    [bon, expérience, évolution, possible, sein, e...
# 167    [opportunité, nombreux, cdd,bonne, structure, ...
# 169    [travail, être, simple, prendre, énormément, t...
# 170    [exécution, ordre, clients, gestion, compte, s...
# 171    [avoir, travailler, bnp, pariba, sourire, tous...
# 172    [organisation, plein, changement, situation, t...
# 173    [bon, gestion, département, ', corporate, buil...
# 174    [salaire, correct, horaire, correct, chèque, r...
# 175    [environnement, agréable,trè, bon, convivialit...
# 176    [entreprise, dynamique, pouvoir, encore, plus,...
# 177    [tant, employé, banque, avoir, plein, possibil...
# 178    [local, parfaitement, entretenure, bnp, pariba...
# 179    [travailler, principalement, monde, immobilier...
# 180    [tant, contrôleur, gestion, contrôleur, financ...
# 181    [travail, être, trop, diviser, être, maillon, ...
# 182    [environnement, travail, agréable, poste, inté...
# 183    [travail, agence, pouvoir, être, aussi, agréab...
# 184    [niveau, horaire, rien, redire, donner, possib...
# 185    [journée, travail, intense, forte, pression, c...
# Name: review_lemmas, dtype: object

# %% [markdown]
# # Création du Bag of Words

# %% [markdown]
# La suppression des mots comme 'je' à l'aide du POS n'est pas efficace. Le mieux est d'établire une liste des mots vides à supprimer. Pour cela on peut utiliser la liste de stop words de nltk

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(bnp_fr['review'])

# %%
vocab = vectorizer.get_feature_names()
nbMots = numpy.sum(X.toarray(),axis=0)

vocab[-200:]
# Out:
# [u'souci',
#  u'soucieux',
#  u'souder',
#  u'souhaiter',
#  u'souple',
#  u'source',
#  u'sourire',
#  u'sous',
#  u'soutenir',
#  u'souvenir',
#  u'souvent',
#  u'spinoff',
#  u'sp\xe9cialis\xe9er',
#  u'sp\xe9cifique',
#  u'st',
#  u'stable',
#  u'stage',
#  u'stagiaire',
#  u'statistique',
#  u'statut',
#  u'strat\xe9gie',
#  u'strict',
#  u'structure',
#  u'structur\xe9',
#  u'succursal',
#  u'succursale',
#  u'suffisamment',
#  u'suite',
#  u'suivi',
#  u'suivre',
#  u'sujet',
#  u'superbe',
#  u'suppl\xe9mentaire',
#  u'sup\xe9rieur',
#  u'sur',
#  u'surcharge',
#  u'surtout',
#  u'surveillance',
#  u'symbiose',
#  u'sympa',
#  u'sympathie',
#  u'sympathique',
#  u'sympathiques',
#  u'synonyme',
#  u'synth\xe8se',
#  u'syst\xe8me',
#  u's\xe9curisation',
#  u's\xe9curit\xe9',
#  u's\xe9rieux',
#  u'tableau',
#  u'taches',
#  u'taille',
#  u'talent',
#  u'talents',
#  u'talentueux',
#  u'tant',
#  u'tarifaire',
#  u'tarificatrice',
#  u'technique',
#  u'techniques',
#  u'temporaire',
#  u'temps',
#  u'terme',
#  u'terminer',
#  u'texte',
#  u'ticketing',
#  u'tickets',
#  u'tier',
#  u'titre',
#  u'titres',
#  u'tomb\xe9es',
#  u'toujour',
#  u'toujours',
#  u'tourner',
#  u'tourn\xe9e',
#  u'tous',
#  u'tout',
#  u'toute',
#  u'toutefois',
#  u'toutes',
#  u'traducteur',
#  u'traduction',
#  u'traitant',
#  u'traitement',
#  u'traiter',
#  u'tranquillit\xe9',
#  u'transmettre',
#  u'transmission',
#  u'transparence',
#  u'transversal',
#  u'transversalit\xe9',
#  u'travail',
#  u'travaille',
#  u'travailler',
#  u'travailleur',
#  u'tre',
#  u'tri',
#  u'trier',
#  u'trois',
#  u'trop',
#  u'trouver',
#  u'tr\xe8',
#  u'tr\xe8s',
#  u'tr\xe9',
#  u'tutelle',
#  u'tuteur',
#  u'types',
#  u'typique',
#  u't\xe2che',
#  u't\xe9l\xe9phone',
#  u't\xe9l\xe9phonique',
#  u't\xe9l\xe9phon\xe9',
#  u't\xe9l\xe9surveillance',
#  u't\xeate',
#  u't\xf4t',
#  u'un',
#  u'une',
#  u'uni',
#  u'unir',
#  u'univers',
#  u'universit\xe9',
#  u'up',
#  u'urgence',
#  u'utile',
#  u'utilisation',
#  u'vacances',
#  u'valeur',
#  u'valoriser',
#  u'varier',
#  u'vari\xe9',
#  u'vari\xe9er',
#  u'vari\xe9t\xe9',
#  u'veiller',
#  u'venir',
#  u'vent',
#  u'vente',
#  u'vie',
#  u'vieux',
#  u'ville',
#  u'virement',
#  u'virements',
#  u'viser',
#  u'vision',
#  u'visites',
#  u'vite',
#  u'vivier',
#  u'vo',
#  u'voir',
#  u'vouloir',
#  u'vous',
#  u'vrai',
#  u'vraiment',
#  u'vu',
#  u'vue',
#  u'v\xe9rification',
#  u'v\xe9ritablement',
#  u'washington',
#  u'workflow',
#  u'workflox',
#  u'xml',
#  u'zone',
#  u'z\xe9ro',
#  u'\xe2ge',
#  u'\xe9change',
#  u'\xe9changer',
#  u'\xe9chelle',
#  u'\xe9ch\xe9ance',
#  u'\xe9ch\xe9ancier',
#  u'\xe9clairage',
#  u'\xe9co',
#  u'\xe9cole',
#  u'\xe9coute',
#  u'\xe9couter',
#  u'\xe9gal',
#  u'\xe9galement',
#  u'\xe9galit\xe9',
#  u'\xe9largir',
#  u'\xe9lectronique',
#  u'\xe9lev\xe9er',
#  u'\xe9l\xe9ment',
#  u'\xe9mission',
#  u'\xe9nergie',
#  u'\xe9norm\xe9ment',
#  u'\xe9panouir',
#  u'\xe9panouissement',
#  u'\xe9pargne',
#  u'\xe9quilibre',
#  u'\xe9quilibrer',
#  u'\xe9quipe',
#  u'\xe9tablissement',
#  u'\xe9tat',
#  u'\xe9tendre',
#  u'\xe9tude',
#  u'\xe9tudier',
#  u'\xe9ventuel',
#  u'\xe9vidence',
#  u'\xe9voluer',
#  u'\xe9voluon',
#  u'\xe9volution',
#  u'\xeatre']

# %%
import operator

# %%
bnp_fr.iloc[130]['reviewDescription']
# Out:
# u'Une entreprise leader sur le march\xe9 mais qui n\'embauche pas les "bons" profils. En effet, l\'entreprise ne fait pas de r\xe9tention des bons talents et ne propose pas un des opportunit\xe9s d\'\xe9volutions comme cela est dit \xe0 l\'embauche.,Par contre, bon \xe9quilibre entre vie priv\xe9e et vie professionnelle.'

# %%
transformer = TfidfTransformer()
tfidf = transformer.fit_transform(X)

# %%
nbMots2 = numpy.sum(tfidf.toarray(),axis=0)

dictionary2 = dict(zip(vocab, nbMots2))
print sorted(dictionary2.items(), key=operator.itemgetter(1))[-20:]
# Out:
# [(u'management', 3.527490273911146), (u'pariba', 3.5393633753193474), (u'journ\xe9e', 3.6162558990728408), (u'environnement', 3.674203986632854), (u'sein', 3.8363854502134775), (u'aspect', 4.0300528977342154), (u'exp\xe9rience', 4.1146444154642268), (u'bnp', 4.2268511854043496), (u'ambiance', 4.4114471794710672), (u'poste', 4.7519625270714982), (u'collaborateur', 4.9169983616573294), (u'plus', 5.0536626362703005), (u'\xe9quipe', 5.5542396713978146), (u'entreprise', 5.9447665555378233), (u'agr\xe9able', 6.5133360896430332), (u'avoir', 7.9502284756701469), (u'tr\xe8s', 8.655740104087533), (u'travail', 9.1711368140836989), (u'bon', 9.4537062393561673), (u'\xeatre', 14.348710158572455)]

# %% [markdown]
# # Décomposition SVD

# %% [raw]
# U :Unitary matrix having left singular vectors as columns. If return_singular_vectors is “vh”, this variable is not computed, and None is returned instead.
# s :The singular values
# Vt :Unitary matrix having right singular vectors as rows. If return_singular_vectors is “u”, this variable is not computed, and None is returned instead.
# k : Number of singular values and vectors to compute. Must be 1 <= k < min(A.shape)

# %%
U, s, Vt = linalg.svds(tfidf, k = 74)

# %%
Vt.shape
# Out:
# (74, 1328)

# %%
len([w for w in s if w > s.mean()])
# Out:
# 26

# %%
sd = numpy.zeros((74,74))

# %%
numpy.fill_diagonal(sd, s)

# %%
sd
# Out:
# array([[ 0.95981613,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.96325461,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.96626265, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  1.74361698,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          1.95999057,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  3.08606425]])

# %%
VS = numpy.dot(numpy.transpose(Vt),sd)

# %%
VS.shape
# Out:
# (1328, 74)

# %% [markdown]
# ### Clustering K-means

# %%
km_model = KMeans(n_clusters=35)

# %%
km_model.fit(VS)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=35, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %%
clustering = collections.defaultdict(list)

# %%
for idx, label in enumerate(km_model.labels_):
    clustering[label].append(idx)

# %%
d ={}

# %%
for label in clustering :
    d[label] = []
    for i in clustering[label]:
        d[label] = d[label]+[vectorizer.get_feature_names()[i]]

# %%
writer = csv.writer(open('dict.csv','wb'))
for key, value in d.items():
    writer.writerow([key, value])

# %% [markdown]
# ### Printing du résultat

# %%
for k in range(0,len(d)):
    print '---------'+'cluster '+ str(k)
    for i in  clustering[k]:
        print vectorizer.get_feature_names()[i]
# Out:
# ---------cluster 0
# analyse
# bilan
# clientèle
# crédit
# disponibilité
# dossier
# former
# management
# pme
# préparation
# ---------cluster 1
# accueillant
# actuariat
# adaptéer
# affaire
# ageable
# agence
# ainsi
# amenére
# améliorer
# année
# antin
# apporteur
# apprentissage
# archivage
# arriver
# assurance
# attitrer
# attractif
# aussi
# bancaire
# bancaires
# brève
# busines
# but
# calculon
# campagne
# cardif
# cependant
# chance
# changéer
# chose
# classement
# classer
# clientele
# coaching
# collectivement
# collègues
# commencer
# concerner
# connaitre
# conseiller
# considéréer
# convivial
# coter
# courant
# court
# courtoises
# devoir
# direct
# direction
# débattre
# déjà
# démarchage
# désaccord
# détection
# effort
# entier
# envie
# espèce
# et
# etant
# exigeant
# facilement
# fermeture
# feutrer
# finalement
# financement
# financiers
# flexible
# fmi
# fois
# formére
# fréquent
# gamme
# grosse
# guichet
# gérer
# habitation
# haut
# image
# incivilité
# inconvénient
# individuellement
# intégrer
# intérimaire
# inventaire
# je
# jusque
# long
# lors
# mailing
# mails
# manager
# mathématique
# matin
# matinée
# mieux
# milieu
# moins
# moment
# montage
# moyen
# niveau
# notaire
# objectif
# oblige
# occasion
# occuper
# optimisation
# organisation
# organiséer
# orienter
# ouvert
# ouverture
# pa
# part
# partager
# partenaire
# particulier
# partir
# passionnant
# pause
# permis
# perspectif
# phoning
# placement
# plupart
# pnb
# points
# ponctuellement
# pote
# principalement
# printemps
# produit
# professionnalisation
# propos
# proposer
# prospect
# provision
# préparer
# présenter
# prévoyance
# question
# rachat
# ranger
# rapidement
# recenti
# relations
# remplacement
# remplies
# rencontrer
# rencontrée
# rendu
# rentabilité
# repartier
# reporting
# reprendre
# reunir
# rien
# rue
# rythme
# réactif
# réalisation
# régulièrement
# répétitif
# réseau
# réunion
# réunir
# secret
# semaine
# sen
# servir
# signaler
# signature
# simulation
# sociaux
# société
# solution
# sommer
# sortant
# soucieux
# souhaiter
# spécialiséer
# spécifique
# stable
# strict
# suivi
# talentueux
# terme
# toujour
# transmettre
# transmission
# travailleur
# trier
# tré
# tutelle
# tête
# unir
# univers
# variéer
# vent
# vente
# véritablement
# washington
# égal
# épargne
# étude
# ---------cluster 2
# avoir
# ---------cluster 3
# être
# ---------cluster 4
# très
# ---------cluster 5
# 06h45
# 100
# 17h30
# 18h30
# 19h00
# 20h
# 360
# 9000000
# aboutir
# accompagnement
# accomplir
# accorder
# accueillante
# achever
# acteur
# action
# actions
# actualisation
# actualité
# actuellement
# adapter
# administration
# affectation
# afférent
# agricole
# ailleurs
# ajouter
# alerte
# aller
# alléger
# alternant
# aléatoire
# ambitieux
# ambition
# amélioration
# amérique
# applications
# appliquéer
# apprenti
# appui
# aprimo
# après
# argentin
# arm
# arrivé
# arrêt
# assister
# atm
# atteindre
# attitude
# au
# augmenter
# auto
# autonome
# autonomie
# autres
# auxiliaire
# avancer
# avancé
# avenir
# back
# badge
# baser
# bases
# baséer
# bgl
# bilingue
# bleu
# boulot
# bourse
# bruyant
# bâtiment
# bémol
# bénéficier
# cac
# café
# candidat
# cantine
# capitalistique
# carte
# cash
# cdd
# cellule
# certes
# cette
# challenger
# challenging
# changement
# changer
# charger
# chef
# chercher
# choisir
# chèques
# circonstance
# classéer
# clier
# coeur
# collégue
# commentaire
# commerce
# commerciaux
# commnication
# commun
# complexe
# compliquéer
# composéer
# compris
# comptable
# compétence
# compétences
# compétition
# concertation
# confiance
# conformité
# conférence
# constant
# constructif
# conséquence
# contestations
# continuer
# contrats
# contrôler
# convenablement
# coopération
# correspondre
# coup
# coupure
# credit
# critiquable
# créer
# cumuler
# côté
# dan
# de
# degré
# demander
# demandeur
# demandéer
# dernier
# derniers
# deux
# dialogue
# difficulté
# dimension
# dire
# directement
# distinguer
# diversification
# diversifié
# doute
# dure
# dynamique
# dysfonctionnement
# débiteurs
# début
# décevoir
# décision
# décrocher
# défaut
# défi
# définie
# délivrance
# démarrer
# départements
# dépasser
# développer
# effectuéer
# effet
# efforcer
# embauche
# embaucher
# employee
# employer
# employés
# en
# encodage
# encore
# enjeux
# entendre
# entente
# entraider
# entrer
# entretenure
# entrée
# equilibre
# erreur
# escalader
# esprit
# essentiel
# etats
# euro
# excel
# excellent
# exceptionnel
# exemple
# exercer
# exercice
# exister
# expérimentéer
# facile
# faciliter
# famille
# favorablement
# façon
# feuille
# fiabilité
# figurer
# fil
# filial
# finance
# flotter
# focu
# fonction
# fonctionnel
# fond
# fonds
# formatrice
# forte
# fr
# france
# fédérateur
# gagner
# garde
# gen
# gentils
# genève
# globalité
# glorifiant
# gm
# gratification
# grave
# gâcher
# génère
# génération
# généréer
# gérance
# gérée
# handicapé
# heure
# honneur
# humainement
# humour
# hésiter
# hôtesse
# ignoréer
# implication
# imposére
# incident
# inclure
# incontournable
# individuel
# indéniablement
# initiatif
# innovation
# intense
# intensif
# interdiction
# interime
# international
# intervenir
# introduire
# intégration
# intéressére
# investir
# investissement
# inégalitaire
# irréprochable
# it
# jamais
# jeun
# joignable
# joinville
# juridiction
# juridique
# juriste
# laquelle
# large
# leader
# ler
# les
# lesquel
# lesquelle
# libre
# local
# logistique
# longu
# là
# main
# maintenir
# manger
# manque
# manquer
# maroc
# matière
# maximum
# maître
# maîtrise
# meeting
# mener
# mentoring
# midi
# miser
# moa
# mobilité
# modification
# mondial
# morale
# moteur
# motivant
# motivation
# motivé
# multirisque
# mécanique
# ne
# nombreuses
# non
# nouvel
# nuire
# nécessite
# négociation
# objectifs
# objet
# obligatoire
# offre
# offrir
# optimiser
# ordinateur
# outre
# ouvertre
# ouvrir
# p24
# parfait
# parfaitement
# participer
# particulièrement
# partie
# partiel
# patron
# pee
# performant
# performer
# perso
# perspectives
# pertiner
# petit
# petite
# peut
# plaire
# plaisir
# plu
# plutôt
# politique
# polyvalence
# pont
# porte
# portée
# positif
# postes
# pourquoi
# prime
# primordial
# principal
# privée
# privéer
# pro
# procédure
# professionel
# profil
# proféssionnels
# prolongéer
# promotion
# prononcéer
# prospectif
# protection
# provoquer
# précaire
# précis
# précisément
# présente
# prêt
# prête
# pub
# qualifié
# quartier
# que
# quelqu
# questions
# rachetee
# raison
# rapide
# rapport
# recette
# redire
# refroidir
# relationnel
# relativement
# relever
# remplier
# remplir
# rencontrére
# renouveler
# renouvellement
# reprise
# requête
# respect
# respectabilité
# responsabilité
# responsable
# ressentir
# ressource
# restructuration
# retourner
# revanche
# reçuer
# riche
# rigide
# réalisées
# réel
# référence
# référentiel
# réglementation
# régularisation
# régularité
# rétention
# sain
# sanction
# santé
# satisfaction
# satisfaitre
# scanner
# scanning
# schéma
# scrupuleusement
# secteur
# selon
# seulement
# situer
# sociable
# socièté
# sollicitation
# sont
# souci
# souder
# souple
# soutenir
# souvenir
# stagiaire
# statut
# structuré
# succursal
# suite
# sujet
# supplémentaire
# supérieur
# sur
# surcharge
# surveillance
# symbiose
# sympathie
# sympathique
# synonyme
# synthèse
# système
# sécurité
# sérieux
# taille
# talent
# tarifaire
# tarificatrice
# technique
# temporaire
# terminer
# tier
# titre
# tombées
# tourner
# toutefois
# toutes
# traiter
# transparence
# transversal
# transversalité
# tre
# trouver
# tuteur
# types
# téléphoné
# télésurveillance
# tôt
# uni
# up
# urgence
# utilisation
# vacances
# veiller
# vie
# ville
# vision
# visites
# vivier
# vo
# vraiment
# vu
# zone
# échanger
# échelle
# échéance
# échéancier
# éclairage
# écoute
# écouter
# également
# égalité
# élargir
# électronique
# émission
# épanouissement
# équilibre
# établissement
# état
# étendre
# éventuel
# évidence
# évoluon
# ---------cluster 6
# compétent
# enrichissant
# humain
# plan
# professionnel
# tant
# ---------cluster 7
# bon
# ---------cluster 8
# expérience
# ---------cluster 9
# bnp
# pariba
# ---------cluster 10
# anglais
# avis
# collecte
# création
# dividende
# dvop
# dvse
# dépositaires
# financier
# fiscalité
# français
# information
# modèle
# opération
# ost
# paiement
# position
# rapprochement
# rédaction
# réçue
# spinoff
# titres
# traitement
# vérification
# ---------cluster 11
# carrière
# culture
# potentiel
# évolution
# ---------cluster 12
# développement
# opportunité
# ---------cluster 13
# 1000
# 800
# 8h
# accompagner
# accueillir
# administratif
# aise
# alors
# anticiper
# apercevoir
# apparenter
# apprendre
# appréciable
# assistance
# attente
# avec
# base
# bel
# bref
# brief
# cas
# ce
# cergy
# charge
# chiffre
# choses
# chèque
# chéquier
# clients
# climat
# code
# collaborateurs
# commerciale
# commerciales
# compliance
# composer
# concluant
# condition
# configuration
# congé
# connaissance
# correct
# crier
# demande
# devenir
# directeur
# discuter
# diversifiée
# donner
# dur
# déler
# délivrer
# démarche
# déontologique
# détail
# effectif
# effectuer
# encaisser
# entenduer
# entité
# environ
# expert
# expertise
# face
# faire
# falloir
# faute
# gentil
# horaire
# hospitalisation
# immobilier
# imparti
# impersonnel
# important
# institution
# intéressant
# intérêt
# itms
# job
# la
# le
# locataire
# lot
# lotu
# mail
# messagerie
# mode
# morning
# multiplicité
# mécontent
# mécontentement
# métier
# nicola
# normal
# notes
# officer
# par
# parfois
# parole
# parti
# patier
# permanent
# plaindre
# plaisante
# pleuvoir
# pousser
# premier
# pression
# prestation
# primauté
# propriétaires
# prospection
# proximité
# période
# pôle
# recevoir
# recommander
# relance
# relatif
# relation
# rencontres
# rendre
# rendure
# renseigner
# rentrée
# repas
# respecter
# rester
# retour
# retrait
# réaliser
# rémunération
# répondre
# résultat
# salaire
# satisfaire
# savoir
# scolaire
# ser
# situation
# source
# st
# stage
# succursale
# suivre
# sympathiques
# taches
# ticketing
# téléphone
# université
# varié
# virement
# virements
# viser
# vite
# zéro
# éco
# étudier
# ---------cluster 14
# collaborateur
# ---------cluster 15
# accueil
# appel
# distance
# gestion
# intervention
# livraison
# matériel
# physique
# place
# ressources
# secrétariat
# tickets
# téléphonique
# ---------cluster 16
# 12h
# 13h
# 14h
# 17h
# 1h
# 55an
# 9h
# acquérir
# adaptation
# affaires
# age
# aider
# analyser
# anglophone
# ans
# apporter
# archives
# atmosphère
# attention
# autant
# autour
# baisse
# bonne
# building
# bureau
# canaux
# cao
# centre
# chargé
# chaîne
# cinq
# cohérent
# cohésion
# comité
# commerces
# communication
# comprendre
# concentrer
# conduiter
# confiére
# consacrer
# conseil
# considération
# consister
# contact
# contribuer
# contrôle
# contrôleur
# convier
# coordonnée
# corporate
# courte
# culturelle
# date
# dessus
# disponible
# disposer
# diviser
# document
# donnée
# durée
# débutant
# débuter
# découverte
# découvrir
# déjeuner
# délaisser
# département
# dépendre
# efficacement
# encadrer
# endroit
# ensemble
# entrepreneur
# experience
# expérimenté
# externe
# favorable
# fier
# finir
# firme
# forces
# forcément
# formateur
# fournir
# garantir
# grand
# grandir
# graphique
# général
# hiérarchie
# il
# importer
# incompréhension
# informatique
# intermédiaire
# intern
# interne
# intérim
# irp
# jeu
# jeune
# juger
# laisser
# liberté
# linguistique
# logiciel
# lutter
# ma
# mai
# maillon
# marchére
# maximale
# mise
# monde
# moyenne
# moyens
# multi
# notamment
# nécessaire
# observéer
# on
# outil
# où
# paisible
# parer
# passer
# passionner
# passéer
# periode
# pertinent
# peu
# plans
# pleinement
# point
# première
# produire
# professionnelle
# projet
# propice
# proposition
# précédent
# quotidien
# rangement
# rdv
# recherche
# regard
# reguler
# repartir
# réceptionner
# régulier
# rôle
# salarié
# sentir
# sept
# services
# seul
# signataire
# simple
# social
# sourire
# sous
# stratégie
# suffisamment
# superbe
# sécurisation
# techniques
# texte
# tout
# toute
# traducteur
# traduction
# traitant
# tranquillité
# travaille
# travailler
# trois
# typique
# utile
# valoriser
# varier
# variété
# venir
# vieux
# voir
# vouloir
# vrai
# vue
# âge
# échange
# élevéer
# énergie
# énormément
# épanouir
# ---------cluster 17
# collaboration
# exécution
# grâce
# membre
# optimale
# ordre
# renduer
# tâche
# ---------cluster 18
# 30
# 65
# aimer
# an
# auprès
# colis
# concernée
# contrat
# courrier
# coursier
# dehors
# extern
# fin
# global
# jour
# navette
# person
# postal
# postaux
# priser
# prévenir
# redistribution
# renseignement
# réception
# site
# statistique
# tableau
# tournée
# tri
# ---------cluster 19
# correcte
# documentaire
# envoi
# equipe
# flux
# lad
# rad
# reconnaissance
# sympa
# workflow
# workflox
# xml
# ---------cluster 20
# autre
# convivialité
# interaction
# intéresser
# requérir
# service
# trè
# ---------cluster 21
# environnement
# ---------cluster 22
# alternance
# assurer
# bnpp
# exprimer
# formation
# permettre
# qualité
# école
# ---------cluster 23
# avantages
# diversité
# emploi
# groupe
# internationale
# marché
# perspective
# sein
# talents
# tous
# ---------cluster 24
# aspect
# difficile
# plus
# poste
# ---------cluster 25
# entreprise
# ---------cluster 26
# ambiance
# ---------cluster 27
# avancement
# banque
# différent
# domaine
# employeur
# enfants
# formare
# fête
# générale
# hiérarchisé
# limiter
# mettre
# noël
# organiser
# personnel
# plein
# possibilité
# progresser
# satisfaisant
# soirée
# souvent
# valeur
# évoluer
# ---------cluster 28
# travail
# ---------cluster 29
# cadre
# chaleureux
# collectif
# collègue
# considérer
# indispensable
# montrére
# réussite
# élément
# ---------cluster 30
# 17an
# alterner
# arrivée
# banal
# beaucoup
# besoin
# challenge
# client
# commercial
# complexes
# compte
# constamment
# débiteur
# entraide
# etc
# mois
# mouvement
# nouveau
# portefeuille
# pouvoir
# prendre
# prise
# préser
# regarder
# rendez
# rigueur
# risque
# six
# toujours
# un
# une
# vous
# ---------cluster 31
# équipe
# ---------cluster 32
# employé
# enorme
# equivalent
# etre
# evolution
# faible
# hierarchie
# interessement
# loin
# nombreux
# numero
# participation
# possible
# sentiment
# structure
# trop
# ---------cluster 33
# accessible
# assez
# bien
# compter
# diverse
# encadrement
# ennuyer
# intéressantes
# journée
# mission
# surtout
# temps
# équilibrer
# ---------cluster 34
# agréable

# %%
for w in stopwords.words('french'):
    print w
# Out:
# au
# aux
# avec
# ce
# ces
# dans
# de
# des
# du
# elle
# en
# et
# eux
# il
# je
# la
# le
# leur
# lui
# ma
# mais
# me
# même
# mes
# moi
# mon
# ne
# nos
# notre
# nous
# on
# ou
# par
# pas
# pour
# qu
# que
# qui
# sa
# se
# ses
# son
# sur
# ta
# te
# tes
# toi
# ton
# tu
# un
# une
# vos
# votre
# vous
# c
# d
# j
# l
# à
# m
# n
# s
# t
# y
# été
# étée
# étées
# étés
# étant
# étante
# étants
# étantes
# suis
# es
# est
# sommes
# êtes
# sont
# serai
# seras
# sera
# serons
# serez
# seront
# serais
# serait
# serions
# seriez
# seraient
# étais
# était
# étions
# étiez
# étaient
# fus
# fut
# fûmes
# fûtes
# furent
# sois
# soit
# soyons
# soyez
# soient
# fusse
# fusses
# fût
# fussions
# fussiez
# fussent
# ayant
# ayante
# ayantes
# ayants
# eu
# eue
# eues
# eus
# ai
# as
# avons
# avez
# ont
# aurai
# auras
# aura
# aurons
# aurez
# auront
# aurais
# aurait
# aurions
# auriez
# auraient
# avais
# avait
# avions
# aviez
# avaient
# eut
# eûmes
# eûtes
# eurent
# aie
# aies
# ait
# ayons
# ayez
# aient
# eusse
# eusses
# eût
# eussions
# eussiez
# eussent

# %%
len(stopwords.words('french'))
# Out:
# 155

# %% [markdown]
# ### LSA

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer

lsa = TruncatedSVD(2, algorithm = 'arpack')
dtm_lsa = lsa.fit_transform(tfidf)
dtm_lsa = Normalizer(copy=False).fit_transform(dtm_lsa)
lsa.explained_variance_ratio_.sum()
# Out:
# 0.03444249778620713

# %%
vec = pandas.DataFrame(lsa.components_,index=["component_1","component_2" ],columns = vectorizer.get_feature_names())
vec
# Out:
#                 06h45       100      1000       12h       13h       14h  \
# component_1  0.007604  0.004945  0.004332  0.010328  0.015875  0.007699
# component_2 -0.008537  0.001838 -0.008827 -0.005443 -0.011676 -0.009341
#
#                  17an       17h     17h30     18h30    ...         état  \
# component_1  0.009590  0.019835  0.004398  0.007604    ...     0.018093
# component_2 -0.020433 -0.001022 -0.002742 -0.008537    ...     0.017913
#
#               étendre     étude   étudier  éventuel  évidence   évoluer  \
# component_1  0.004101  0.012869  0.011920  0.001343  0.002639  0.056008
# component_2 -0.004496 -0.007059 -0.009301 -0.003177 -0.002758 -0.030521
#
#               évoluon  évolution      être
# component_1  0.003597   0.071680  0.438150
# component_2 -0.005831   0.035012 -0.292565
#
# [2 rows x 1328 columns]

# %%
pandas.DataFrame(dtm_lsa, index = bnp_fr['review'], columns = ["component_1","component_2" ])
# Out:
#                                                     component_1  component_2
# review
# poste intéresser beaucoup formation bon entente...     0.758746     0.651386
# être agréable travailler bnp pariba projet pers...     0.953274    -0.302108
# travailler beaucoup person compétent                   0.993126    -0.117047
# equipe sympa ambiance correcte envoi flux xml r...     0.897852     0.440297
# stage agréable premier mission adaptéer niveau ...     0.856778     0.515686
# periode trop courte juger bon experience bon re...     0.430480     0.902600
# agence joinville pont environnement travail êtr...     0.712329     0.701846
# journée consister effectuer surveillance compte...     0.966572    -0.256396
# sein bnp pariba avoir avoir chance être tutelle...     0.829606    -0.558349
# bon entreprise très bon ambiance sein entreprise       0.621780     0.783192
# poste occuper actuellement être transversal tâc...     0.843597    -0.536977
# journée travail agréable globalité personnel sy...     0.890243    -0.455485
# développement formation être opportunité évolue...     0.978773    -0.204947
# rythme travail soutenir parfait développement r...     0.905876     0.423544
# excellent relation différent service différent ...     0.931119    -0.364716
# préparation journée préparer poste travail occu...     0.955612    -0.294628
# suivre très satisfaire journée travail bnp pariba      0.936617     0.350356
# collègue être gentil travail dur avoir améliore...     0.954856    -0.297070
# charge travail être important avoir énormément ...     0.979243    -0.202691
# être contrat professionnalisation alternance gé...     0.689788    -0.724011
# grosse société avantages inconvénient avoir tra...     0.780561    -0.625079
# peu conseil beaucoup commercial bon première ex...     0.984989     0.172617
# normal rentrée scolaire période effectif travai...     0.982352    -0.187039
# bnp pariba cardif pouvoir mettre bon accompagne...     0.998552     0.053787
# avoir effectuer stage 3 mois sein succursale bn...     0.870494    -0.492180
# priser considération salarié bon cohésion équipe       0.537938     0.842985
# journée travail composer morning brief gestion ...     0.888011    -0.459822
# charger administration crédit être poste traite...     0.723575    -0.690245
# convivialité très bon esprit équipe sein servic...     0.701495     0.712675
# journée travail toujours très satisfaisant empl...     0.749552     0.661946
# ...                                                         ...          ...
# bel expérience professionnel travailler intéres...     0.997847     0.065589
# équipe corporate finance bnp pariba être très e...     0.993144     0.116902
# horaire être assez flexible taches demandéer êt...     0.990066    -0.140603
# équipe agréable travail varier environnement ag...     0.753500     0.657448
# cadre travail être agréable collègue être montr...     0.991357     0.131190
# bon employeur général banque français très hiér...     0.546020     0.837772
# entreprise permettre développer compétence acqu...     0.936626    -0.350332
# négociation téléphonique fr régularisation éché...     0.806670    -0.591003
# entreprise professionnel international connaiss...     0.999090     0.042645
# expérience sein bnp pariba qualité juriste fina...     0.921497    -0.388386
# être plus ouvertre jeun candidat manquer experi...     0.852940    -0.522009
# bon expérience évolution possible sein entrepri...     0.747297     0.664490
# opportunité nombreux cdd bon structure travail ...     0.886063    -0.463565
# travail être simple prendre énormément temps           0.954631    -0.297790
# exécution ordre clients gestion compte suivre r...     0.611365    -0.791349
# avoir travailler bnp pariba sourire tous jour t...     0.922489    -0.386024
# organisation plein changement situation très co...     0.762819     0.646612
# bon gestion département ' corporate building ' ...     0.754773     0.655986
# salaire correct horaire correct chèque repas ch...     0.971088    -0.238721
# environnement agréable très bon convivialité tr...     0.554928     0.831898
# entreprise dynamique pouvoir encore plus dévelo...     0.905236    -0.424910
# tant employé banque avoir plein possibilité évo...     0.951296    -0.308280
# local parfaitement entretenure bnp pariba genèv...     0.969808    -0.243869
# travailler principalement monde immobilier ; se...     0.812896    -0.582408
# tant contrôleur gestion contrôleur financier ex...     0.999234     0.039134
# travail être trop diviser être maillon très gra...     0.999727     0.023346
# environnement travail agréable poste intéresser...     0.798199     0.602393
# travail agence pouvoir être aussi agréable dive...     0.914544    -0.404487
# niveau horaire rien redire donner possibilité m...     0.892909    -0.450236
# journée travail intense forte pression commerci...     0.969332     0.245754
#
# [174 rows x 2 columns]

# %% [markdown]
# ### LDA

# %% [markdown]
# from __future__ import print_function
# from time import time
#
# from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
# from sklearn.decomposition import NMF, LatentDirichletAllocation
# from sklearn.datasets import fetch_20newsgroups
#
# n_samples = 2000
# n_features = 1000
# n_topics = 10
# n_top_words = 20
#
#
# def print_top_words(model, feature_names, n_top_words):
#     for topic_idx, topic in enumerate(model.components_):
#         print("Topic #%d:" % topic_idx)
#         print(" ".join([feature_names[i]
#                         for i in topic.argsort()[:-n_top_words - 1:-1]]))
#     print()
#
#
# # Load the 20 newsgroups dataset and vectorize it. We use a few heuristics
# # to filter out useless terms early on: the posts are stripped of headers,
# # footers and quoted replies, and common English words, words occurring in
# # only one document or in at least 95% of the documents are removed.
#
#
# # Fit the NMF model
# print("Fitting the NMF model with tf-idf features,"
#       "n_samples=%d and n_features=%d..."
#       % (n_samples, n_features))
# t0 = time()
# nmf = NMF(n_components=n_topics, random_state=1, alpha=.1, l1_ratio=.5).fit(tfidf)
# exit()
# print("done in %0.3fs." % (time() - t0))
#
# print("\nTopics in NMF model:")
# tfidf_feature_names = vectorizer.get_feature_names()
# print_top_words(nmf, tfidf_feature_names, n_top_words)

# %% [markdown]
# ### NLTK

# %%
from nltk.collocations import *
bigram_measures = nltk.collocations.BigramAssocMeasures()
#trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder = BigramCollocationFinder.from_words(txt)
finder.nbest(bigram_measures.pmi, 20)# doctest: +NORMALIZE_WHITESPACE
# Out:
# [(u'18h30', u'19h00'),
#  (u'360', u'degr\xe9'),
#  (u'800', u'1000'),
#  (u'aboutir', u'promotion'),
#  (u'accueillant', u'n\xe9cessiter'),
#  (u'acteur', u'incontournable'),
#  (u'aff\xe9rent', u'dernier'),
#  (u'agricole', u'distinguer'),
#  (u'alerte', u'g\xe9n\xe9r\xe9er'),
#  (u'al\xe9atoire', u'cinq'),
#  (u'ambitieux', u'outre'),
#  (u'am\xe9lioration', u'ma\xeetrise'),
#  (u'analyser', u'repartir'),
#  (u'appliqu\xe9er', u'convenablement'),
#  (u'apporteur', u'affaire'),
#  (u'aprimo', u'arm'),
#  (u'argentin', u'sanction'),
#  (u'attitude', u'certes'),
#  (u'augmenter', u'statut'),
#  (u'auxiliaire', u'vacance')]

# %%
import itertools
blocklist =['\xeatre','avoir','tres','plus','bon']
corp = bnp_fr['review_lemmas'].map(lambda x : [t for t in x if t not in blocklist])
corp = list(itertools.chain.from_iterable(corp.tolist()))

txt = nltk.Text(corp)
txt.collocations()
# Out:
# bnp pariba; aspect difficile; aspect agréable; opportunité
# développement; journée travail; ambiance travail; difficile poste;
# miser place; environnement travail; culture entreprise; possibilité
# évolution; très sympathique; fois semaine; pression commercial; poste
# occuper; 12h 13h; exécution ordre; permettre acquérir; cohésion
# équipe; compte rendre
# /anaconda/envs/Python2.7/lib/python2.7/site-packages/ipykernel/__main__.py:3: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   app.launch_new_instance()

# %% [markdown]
# # Gensim

# %%
import gensim

# %%
#blocklist = ['\xeatre','avoir','tr\xe8s']
#bnp_fr['review2'] = bnp_fr['review'].apply(lambda x: [t for t in x if t not in blocklist])
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(corp)

corpus=vectorizer.get_feature_names()
id2words = dict((v, k) for k, v in vectorizer.vocabulary_.iteritems())
corpus_gensim = gensim.matutils.Sparse2Corpus(X, documents_columns=False)

# %%
lda = gensim.models.ldamodel.LdaModel(corpus_gensim, id2word=id2words, num_topics=5, update_every=1, chunksize=1000, passes=1)
lda.print_topics()
# Out:
# [(0,
#   u'0.054*agr\xe9able + 0.029*faire + 0.024*coll\xe8gue + 0.023*professionnel + 0.020*service + 0.019*sein + 0.018*autre + 0.017*employ\xe9 + 0.015*tous + 0.014*toujours'),
#  (1,
#   u'0.219*\xeatre + 0.040*entreprise + 0.034*clients + 0.030*environnement + 0.028*gestion + 0.025*pariba + 0.024*groupe + 0.022*permettre + 0.021*agence + 0.019*contact'),
#  (2,
#   u'0.047*collaborateur + 0.037*\xe9quipe + 0.025*aspect + 0.023*\xe9volution + 0.022*formation + 0.018*temps + 0.011*bien + 0.010*d\xe9velopper + 0.010*pression + 0.009*monde'),
#  (3,
#   u'0.069*tr\xe8s + 0.034*pouvoir + 0.029*bnp + 0.024*management + 0.018*commercial + 0.017*t\xe2che + 0.014*difficile + 0.014*opportunit\xe9 + 0.013*aussi + 0.012*banque'),
#  (4,
#   u'0.083*travail + 0.030*poste + 0.023*travailler + 0.021*journ\xe9e + 0.020*ambiance + 0.020*possibilit\xe9 + 0.018*exp\xe9rience + 0.014*personnel + 0.013*d\xe9veloppement + 0.011*varier')]

# %% [markdown]
# ### Pattern

# %%
from pattern.metrics import cooccurrence

# %%
m = cooccurrence(corp, window=(-3, -3),
      term1 = lambda w: True,
      term2 = lambda w: True,
  normalize = lambda w: w)

# %%
m
# Out:
# {u'succursale': {u'3': 1},
#  u'reprendre': {u'fin': 1},
#  u'code': {u'faire': 1},
#  u'participation': {u'etre': 1},
#  u'maximum': {u'difficile': 1},
#  u'dessus': {u'projet': 1, u'venir': 1},
#  u'global': {u'fin': 1},
#  u'ost': {u'dvse': 1},
#  u'\u20ac': {u'cr\xe9dit': 1},
#  u'baisse': {u'rdv': 1},
#  u'int\xe9rimaire': {u'beaucoup': 1},
#  u'retour': {u'courte': 1, u'parole': 1},
#  u'\xe9voluon': {u'poste': 1},
#  u'aider': {u'd\xe9butant': 1, u'toujours': 1, u'tr\xe8s': 1},
#  u'limiter': {u'hi\xe9rarchiser': 1, u'responsables': 1},
#  u'gm': {u'travailler': 1},
#  u'faute': {u'dessus': 1},
#  u's\xe9curit\xe9': {u'pee': 1},
#  u'entendre': {u'groupe': 1},
#  u'sympa': {u'person': 1},
#  u'obliger': {u'trop': 1},
#  u'facilement': {u'savoir-faire': 1},
#  u'fran\xe7ais': {u'employeur': 1, u'r\xe9daction': 1},
#  u'devenir': {u'aspect': 1, u'opportunit\xe9': 1},
#  u'pouvoir': {u'bnp': 1,
#   u'candidat': 1,
#   u'carri\xe8re': 1,
#   u'cependant': 1,
#   u'circonstance': 1,
#   u'connaissance': 1,
#   u'convenablement': 1,
#   u'dialogue': 1,
#   u'donner': 1,
#   u'dur': 1,
#   u'facilement': 1,
#   u'hi\xe9rarchie': 1,
#   u'int\xe9resser': 1,
#   u'logiciel': 1,
#   u'miser': 1,
#   u'objet': 1,
#   u'optimiser': 1,
#   u'perso': 1,
#   u'pouvoir': 1,
#   u'rencontrer': 1,
#   u'service': 1,
#   u'travail': 1,
#   u'\xe9quipe': 1,
#   u'\xeatre': 4},
#  u'donner': {u'clier': 1,
#   u'horaire': 1,
#   u'objectif': 1,
#   u'partir': 1,
#   u'responsabilit\xe9': 1,
#   u'sch\xe9ma': 1,
#   u'\xeatre': 2},
#  u'pr\xe9senter': {u'coll\xe8gue': 1, u'juridiction': 1},
#  u'\xab': {u'formation': 1},
#  u'technique': {u'apporter': 1, u'permettre': 1, u'plan': 1},
#  u'lors': {u'entreprise': 1, u'poste': 1, u'tr\xe8s': 1},
#  u'incontournable': {u'international': 1},
#  u'charge': {u'am\xe9liorer': 1,
#   u'autres': 1,
#   u'proc\xe9dure': 1,
#   u't\xe2che': 1},
#  u'immobilier': {u'base': 1,
#   u'commercial': 1,
#   u'correct': 1,
#   u'dossier': 1,
#   u'travailler': 1},
#  u'd\xe9couverte': {u'job': 1, u'journ\xe9e': 1, u'proposition': 1},
#  u'suite': {u'formation': 1, u'monde': 1, u'service': 1},
#  u'\xbb': {u'd\xe9veloppement': 1},
#  u'guichet': {u'alternance': 1, u'diversifi\xe9': 1, u'd\xe9but': 1},
#  u'libert\xe9': {u'intern': 1},
#  u'impersonnel': {u'pression': 1},
#  u'objet': {u'erreur': 1, u'exercice': 1},
#  u'd\xe9j\xe0': {u'mail': 1},
#  u'commerce': {u'commercial': 1, u'n\xe9cessaire': 1},
#  u'bnpp': {u'travail': 1},
#  u'6': {u'bancaire': 1, u'collaborateur': 1},
#  u'hi\xe9rarchiser': {u'banque': 1},
#  u'projet': {u'aider': 1,
#   u'collaborateur': 1,
#   u'forces': 1,
#   u'objectif': 1,
#   u'travailler': 1,
#   u'valeur': 1},
#  u'in\xe9galitaire': {u'b\xe9n\xe9ficier': 1},
#  u'\xe9tudier': {u'diversit\xe9': 1, u'poste': 1},
#  u'gratification': {u'tarifaire': 1},
#  u'restructuration': {u'travail': 1},
#  u'pression': {u'appel': 1,
#   u'difficile': 1,
#   u'gestion': 1,
#   u'limiter': 1,
#   u'moins': 1,
#   u'travail': 1},
#  u'ticket': {u'avantages': 1},
#  u'voir': {u'analyser': 1, u'cadre': 1, u'\xeatre': 1},
#  u'coupure': {u'long': 1},
#  u'condition': {u'environnement': 1},
#  u'tri': {u'postal': 1},
#  u'professionnalisation': {u'convivialit\xe9': 1},
#  u'bas\xe9er': {u'diversifi\xe9e': 1},
#  u'courrier': {u'fermeture': 1,
#   u'h': 1,
#   u'poste': 1,
#   u'r\xe9pondre': 1,
#   u'virement': 1,
#   u'\xeatre': 1},
#  u'notes': {u'configuration': 1},
#  u'tre': {u'esprit': 1},
#  u'solution': {u'aspect': 1, u'assurance': 1, u'conseiller': 1},
#  u'souvenir': {u'humainement': 1},
#  u'leader': {u'management': 1, u'o\xf9': 1},
#  u'large': {u'vivier': 1},
#  u'proposition': {u'attention': 1,
#   u'besoin': 1,
#   u'bien': 1,
#   u'r\xe9pondre': 1},
#  u'assurance': {u'actions': 1,
#   u'busines': 1,
#   u'cong\xe9': 1,
#   u'cr\xe9dit': 1,
#   u'nicola': 1,
#   u'proposer': 1,
#   u'rapport': 1},
#  u'partager': {u'faire': 1},
#  u'rencontr\xe9re': {u'\xe9couter': 1},
#  u'poste': {u'*': 1,
#   u'administration': 1,
#   u'ainsi': 1,
#   u'ambiance': 1,
#   u'apporter': 1,
#   u'aspect': 2,
#   u'cependant': 1,
#   u'client': 1,
#   u'collaborateur': 1,
#   u'communication': 1,
#   u'diff\xe9rent': 2,
#   u'donner': 1,
#   u'entreprise': 1,
#   u'environnement': 1,
#   u'faute': 1,
#   u'internationale': 1,
#   u'int\xe9ressant': 1,
#   u'jour': 1,
#   u'lotu': 1,
#   u'paiement': 1,
#   u'personnel': 1,
#   u'perspectives': 1,
#   u'poste': 1,
#   u'pr\xe9paration': 1,
#   u'question': 1,
#   u'satisfaitre': 1,
#   u'sous-traitant': 1,
#   u'sympathique': 1,
#   u'tant': 1,
#   u'temporaire': 1,
#   u'tous': 1,
#   u'tr\xe8s': 1,
#   u't\xe2che': 1,
#   u'urgence': 1,
#   u"y'er": 1,
#   u'\xe9panouissement': 1,
#   u'\xe9quipe': 1,
#   u'\xeatre': 4},
#  u'actuellement': {u'entreprise': 1},
#  u'challenge': {u'diversifi\xe9e': 1,
#   u'esprit': 1,
#   u'forte': 1,
#   u'op\xe9ration': 1},
#  u'interaction': {u'poste': 1},
#  u'semaine': {u'agence': 1, u'fermeture': 1},
#  u'fonctionnel': {u'riche': 1},
#  u'nombreux': {u'avenir': 1,
#   u'derni\xe8re': 1,
#   u'd\xe9couverte': 1,
#   u'd\xe9veloppement': 1,
#   u'evolution': 1,
#   u'groupe': 1,
#   u'g\xe2chent': 1,
#   u'opportunit\xe9': 1,
#   u't\xe9l\xe9phonique': 1},
#  u'relativement': {u'dynamique': 1, u'd\xe9veloppement': 1},
#  u'diversifi\xe9': {u'travail': 1, u'\xeatre': 1},
#  u'directement': {u'\xeatre': 1},
#  u'exp\xe9rience': {u'acqu\xe9rir': 1,
#   u'ajouter': 1,
#   u'assez': 1,
#   u'beaucoup': 1,
#   u'communication': 1,
#   u'difficult\xe9': 1,
#   u'effort': 1,
#   u'entier': 1,
#   u'esprit': 1,
#   u'evolution': 1,
#   u'gestion': 1,
#   u'plaisir': 1,
#   u'suivi': 1,
#   u'sympathie': 1,
#   u'toujours': 1,
#   u'travail': 1,
#   u'\xe9quipe': 1,
#   u'\xeatre': 3},
#  u'colis': {u'dehors': 1, u'extern': 1},
#  u'pr\xeate': {u'arriv\xe9e': 1},
#  u'pme': {u'dossier': 1},
#  u't\xe9l\xe9phonique': {u'assister': 1,
#   u'commercial': 1,
#   u'communication': 1,
#   u'd\xe9livrance': 1,
#   u'formation': 1,
#   u'gestion': 1,
#   u'\xeatre': 1},
#  u'risque': {u'arriv\xe9e': 1, u'\xeatre': 1},
#  u'perspective': {u'emploi': 1},
#  u'd\xe9cevoir': {u'possible': 1},
#  u'affectation': {u'ressource': 1},
#  u'comptable': {u'importer': 1, u'solution': 1},
#  u'cao': {u'varier': 1},
#  u'fonction': {u'3': 1, u'organis\xe9er': 1, u'proposition': 1},
#  u'd\xe9livrer': {u'conseiller': 1, u'pleuvoir': 1},
#  u'employeur': {u'montr\xe9re': 1, u'toujours': 1},
#  u'agricole': {u'rachetee': 1},
#  u'disponible': {u'commercial': 1,
#   u'poste': 1,
#   u'prolong\xe9er': 1,
#   u'tous': 1,
#   u'travail': 1,
#   u'travailler': 1},
#  u'tranquillit\xe9': {u'libert\xe9': 1},
#  u'+': {u'r\xe9ception': 1, u'\xeatre': 1},
#  u'moyens': {u'avantages': 1},
#  u'firme': {u'\xeatre': 1},
#  u'brief': {u'travail': 1},
#  u'\xe9l\xe9ment': {u'employ\xe9': 1},
#  u'f\xe9d\xe9rateur': {u'\xe9couter': 1},
#  u'importer': {u'd\xe9veloppement': 1,
#   u'pariba': 1,
#   u'rendre': 1,
#   u'\xe9quipe': 1},
#  u'actualisation': {u'actualit\xe9': 1, u'compte': 1},
#  u'\xe9changer': {u'manager': 1},
#  u'effectif': {u'rentr\xe9e': 1},
#  u'd\xe9veloppement': {u'bnp': 1,
#   u'challenge': 1,
#   u'conf\xe9rence': 1,
#   u'contr\xf4le': 1,
#   u'd\xe9cision': 1,
#   u'encore': 1,
#   u'environnement': 1,
#   u'journ\xe9e': 1,
#   u'peu': 1,
#   u'renouveler': 1,
#   u'travail': 2,
#   u'tr\xe8s': 1},
#  u'international': {u'impos\xe9re': 1,
#   u'int\xe9ressant': 1,
#   u'pariba': 1,
#   u'\xe9quipe': 1,
#   u'\xeatre': 1},
#  u';': {u'ambiance': 1, u'principalement': 1},
#  u'rachat': {u'faire': 1},
#  u'assister': {u'protection': 1},
#  u'manager': {u'cellule': 1,
#   u'collectif': 1,
#   u'personnel': 1,
#   u'rapprochement': 1},
#  u'charg\xe9': {u'management': 1},
#  u'groupe': {u'agence': 1,
#   u'beaucoup': 1,
#   u'bnp': 1,
#   u'client': 1,
#   u'compliance': 1,
#   u'entreprise': 1,
#   u'faire': 2,
#   u'garde': 1,
#   u'jour': 1,
#   u'journ\xe9e': 1,
#   u'lesquelle': 1,
#   u'march\xe9': 1,
#   u'monde': 1,
#   u'plan': 1,
#   u'respectabilit\xe9': 1,
#   u'travail': 1,
#   u'\xeatre': 1},
#  u'sourire': {u'travailler': 1},
#  u'\xe9galit\xe9': {u'mati\xe8re': 1},
#  u'tourn\xe9e': {u'renseignement': 1},
#  u'discuter': {u'agr\xe9able': 1, u'r\xe9unir': 1},
#  u'contr\xf4ler': {u'structur\xe9': 1},
#  u'commercial': {u'agr\xe9able': 1,
#   u'appel': 1,
#   u'beaucoup': 1,
#   u'but': 1,
#   u'client': 1,
#   u'clients': 1,
#   u'cr\xe9dit': 1,
#   u'exemple': 1,
#   u'exp\xe9rience': 1,
#   u'faire': 1,
#   u'formation': 1,
#   u'gestion': 1,
#   u'guichet': 1,
#   u'humain': 1,
#   u'incivilit\xe9': 1,
#   u'intense': 1,
#   u'personnel': 1,
#   u'peu': 1,
#   u'poste': 1,
#   u'sein': 1,
#   u'tant': 1,
#   u'temps': 1,
#   u'travail': 1,
#   u't\xe9l\xe9phonique': 1,
#   u'\xe9quipe': 1},
#  u'aprimo': {u'rapport': 1},
#  u'\xe9volution': {u'bureau': 1,
#   u'cdd': 1,
#   u'cha\xeene': 1,
#   u'commercial': 1,
#   u'concerner': 1,
#   u'culture': 1,
#   u'face': 1,
#   u'formation': 1,
#   u'fournir': 1,
#   u'groupe': 2,
#   u'mieux': 1,
#   u'peu': 1,
#   u'poste': 1,
#   u'proposer': 1,
#   u'talent': 1,
#   u'tourner': 1,
#   u'travail': 1,
#   u'valeur': 1,
#   u'vent': 1},
#  u'courtoise': {u'o\xf9': 1},
#  u'ranger': {u'toujours': 1},
#  u'pause': {u'8h': 1, u'ainsi': 1, u'aussi': 1, u'professionnel': 1},
#  u'euro': {u'r\xe9f\xe9rence': 1},
#  u'situation': {u'organisation': 1, u'parfois': 1},
#  u'maroc': {u'travail': 1},
#  u'accompagner': {u'commercial': 1},
#  u'g\xe9n\xe9ration': {u'pr\xe9paration': 1},
#  u'miser': {u'aspect': 1, u'satisfaction': 1, u'tout': 1},
#  u'\xe9couter': {u'agr\xe9able': 1,
#   u'gr\xe2ce': 1,
#   u'heure': 1,
#   u'membre': 1,
#   u'moa': 1,
#   u'plaire': 1,
#   u'stage': 1,
#   u'toujours': 1,
#   u'tr\xe8s': 1,
#   u'\xe9quipe': 1,
#   u'\xeatre': 1},
#  u'souhaiter': {u'flexible': 1},
#  u'tr\xe9': {u'cdd': 1,
#   u'conseiller': 1,
#   u'management': 1,
#   u'titres\u2026': 1},
#  u'assurer': {u'compte': 1,
#   u'fiabilit\xe9': 1,
#   u'juridique': 1,
#   u'suivre': 1,
#   u'\xe9quipe': 1},
#  u'rdv': {u'nouveau': 1},
#  u'talent': {u'entreprise': 1, u'important': 1},
#  u'endroit': {u'social': 1},
#  u'informatique': {u'moins': 1, u'patier': 1, u'texte': 1},
#  u'compliance': {u'd\xe9cision': 1, u'financier': 1, u'tr\xe8s': 1},
#  u'beaucoup': {u'agr\xe9able': 1,
#   u'ambiance': 1,
#   u'assez': 1,
#   u'commercial': 1,
#   u'd\xe9couvrir': 1,
#   u'embauche': 1,
#   u'filial': 1,
#   u'important': 1,
#   u'm\xe9tier': 1,
#   u'plans': 1,
#   u'point': 1,
#   u'temps': 1,
#   u'tr\xe8s': 1,
#   u'tr\xe9': 1,
#   u'varier': 1,
#   u'washington': 1,
#   u'\xeatre': 1},
#  u'efficacement': {u'management': 1},
#  u'experience': {u'jeun': 1, u'trop': 1},
#  u'permis': {u'\xeatre': 1},
#  u'credit': {u'exister': 1},
#  u'gr\xe2ce': {u'mettre': 1,
#   u'm\xe9tier': 1,
#   u'r\xe9guli\xe8rement': 1,
#   u'\xeatre': 1},
#  u'perso': {u'tout': 1},
#  u'entier': {u'consid\xe9rer': 1, u'consid\xe9r\xe9er': 1},
#  u'action': {u'accueil': 1},
#  u'vie': {u'carri\xe8re': 1,
#   u'dire': 1,
#   u'employ\xe9': 1,
#   u'structure': 1,
#   u'tomb\xe9es': 1,
#   u'unir': 1,
#   u'\xe9quilibre': 1,
#   u'\xe9quilibrer': 1},
#  u'globalit\xe9': {u'journ\xe9e': 1},
#  u'prolong\xe9er': {u'mois': 1},
#  u'envoi': {u'clier': 1, u'sympa': 1},
#  u'changer': {u'\xe9volution': 1},
#  u'r\xe9ceptionner': {u'journ\xe9e': 1},
#  u'inventaire': {u'\xe9tude': 1},
#  u'9h': {u'notaire': 1, u'travail': 1},
#  u'bruyant': {u'non': 1},
#  u'aimer': {u'+': 1, u'mois': 1, u'\xeatre': 1},
#  u'investir': {u'beaucoup': 1},
#  u'humour': {u'particuli\xe8rement': 1},
#  u'texte': {u'date': 1, u'd\xe9ler': 1},
#  u'filial': {u'in\xe9galitaire': 1},
#  u'auto-formation': {u'effectu\xe9er': 1, u'synonyme': 1},
#  u'ressources': {u'physique': 1, u'qualit\xe9': 1},
#  u'employ\xe9': {u'ambiance': 1,
#   u'attente': 1,
#   u'aussi': 1,
#   u'gratification': 1,
#   u'l\xe0': 1,
#   u'monde': 1,
#   u'technique': 1,
#   u'traducteur': 1,
#   u'tr\xe8s': 1,
#   u'\xe9couter': 1,
#   u'\xeatre': 1},
#  u'enorme': {u'large': 1},
#  u'sympathique': {u'accueil': 1,
#   u'agr\xe9able': 1,
#   u'management': 1,
#   u'r\xe9alisation': 1,
#   u'travail': 1,
#   u'tr\xe8s': 1},
#  u'morale': {u'compte': 1},
#  u'\xe9nergie': {u'difficile': 1},
#  u'performer': {u'\xeatre': 1},
#  u'entreprise': {u'"': 1,
#   u'acqu\xe9rir': 1,
#   u'agricole': 1,
#   u'agr\xe9able': 1,
#   u'aussi': 1,
#   u'avantages': 1,
#   u'bien': 1,
#   u'clients': 1,
#   u'compter': 1,
#   u'concluant': 1,
#   u'cr\xe9dit': 1,
#   u'demandeur': 1,
#   u'essentiel': 1,
#   u'exp\xe9rience': 1,
#   u'faire': 1,
#   u'gr\xe2ce': 1,
#   u'g\xe9n\xe9ral': 1,
#   u'journ\xe9e': 1,
#   u'opportunit\xe9': 1,
#   u'permanent': 1,
#   u'possibilit\xe9': 1,
#   u'premier': 1,
#   u'primordial': 1,
#   u'respect': 1,
#   u'respecter': 1,
#   u'rester': 1,
#   u'sein': 1,
#   u'service': 1,
#   u'signaler': 1,
#   u'travail': 2,
#   u'tr\xe8s': 1,
#   u'utile': 1,
#   u'vie': 1,
#   u'\xe9lev\xe9er': 1,
#   u'\xe9volution': 1},
#  u'composer': {u'\xe9quipe': 1},
#  u'sanction': {u'\xeatre': 1},
#  u'unir': {u'd\xe9partement': 1},
#  u'avantages': {u'autre': 1,
#   u'employ\xe9': 1,
#   u'environnement': 1,
#   u'grosse': 1,
#   u'management': 1,
#   u'offre': 1,
#   u'part': 1,
#   u'particulier': 1,
#   u'travail': 1},
#  u'pleuvoir': {u'beaucoup': 1},
#  u'cr\xe9ation': {u'clients': 1, u'fran\xe7ais': 1, u'\xeatre': 1},
#  u'coh\xe9sion': {u'g\xe9rer': 1, u'priser': 1, u'\xeatre': 1},
#  u'entretenure': {u'collaborateur': 1},
#  u'conduiter': {u'hi\xe9rarchie': 1},
#  u'introduire': {u'maintenir': 1},
#  u'encaisser': {u'contact': 1},
#  u'etats-uni': {u'\xeatre': 1},
#  u'no\xebl': {u'soir\xe9e': 1},
#  u'satisfaire': {u'courrier': 1, u'gagner': 1, u'maximum': 1},
#  u'commun': {u'assurance': 1},
#  u'\xe9cole': {u'd\xe9veloppement': 1},
#  u'encadrer': {u'environnement': 1, u'linguistique': 1},
#  u'univers': {u'direction': 1},
#  u'baser': {u'priser': 1},
#  u'strat\xe9gie': {u'observ\xe9er': 1},
#  u'france': {u'acteur': 1, u'responsable': 1},
#  u'sous-traitant': {u'\xeatre': 1},
#  u'bases': {u'client': 1, u'courrier': 1},
#  u'op\xe9ration': {u'besoin': 1,
#   u'd\xe9couvrir': 1,
#   u'entreprise': 1,
#   u'expertise': 1,
#   u'guichet': 1,
#   u'rendez-vous': 1,
#   u'tout': 1,
#   u'\uf0d8': 1},
#  u'centre': {u'o\xf9': 1},
#  u'assistance': {u'cependant': 1},
#  u'\xe9quipe': {u'9': 1,
#   u'accueil': 1,
#   u'agr\xe9able': 1,
#   u'avancer': 1,
#   u'bien': 1,
#   u'consid\xe9ration': 1,
#   u'contact': 1,
#   u'continuer': 1,
#   u'contrat': 1,
#   u'convivialit\xe9': 1,
#   u'disponible': 1,
#   u'enrichissant': 1,
#   u'faire': 1,
#   u'gestion': 1,
#   u'gm': 1,
#   u'gr\xe2ce': 1,
#   u'habitation': 1,
#   u'interime': 1,
#   u'interne': 1,
#   u'personnel': 1,
#   u'plan': 1,
#   u'portefeuille': 1,
#   u'possibilit\xe9': 1,
#   u'projet': 1,
#   u'quotidien': 1,
#   u'recette': 1,
#   u'r\xe9alis\xe9er': 1,
#   u'sein': 1,
#   u'social': 1,
#   u'souci': 1,
#   u'surtout': 1,
#   u'travail': 1,
#   u'travailler': 1,
#   u'vite': 1,
#   u'\xeatre': 3},
#  u'diversification': {u'groupe': 1},
#  u'circonstance': {u'd\xe9pendre': 1},
#  u'disponibilit\xe9': {u'distance': 1},
#  u'atmosph\xe8re': {u'humain': 1, u'tr\xe8s': 1, u'vue': 1},
#  u'mois': {u'beaucoup': 1, u'compte': 1, u'effectuer': 1},
#  u'lutter': {u'entreprise': 1},
#  u'feutrer': {u'communication': 1},
#  u'coop\xe9ration': {u'collaborateur': 1},
#  u'finir': {u'journ\xe9e': 1},
#  u'soci\xe8t\xe9': {u'\xe9norm\xe9ment': 1},
#  u'convier': {u'prendre': 1},
#  u'site': {u'+': 1, u'site': 1},
#  u'repartier': {u'fin': 1},
#  u'\xe9ch\xe9ancier': {u't\xe9l\xe9phonique': 1},
#  u'appel': {u'clients': 1,
#   u'contrat': 1,
#   u'date': 1,
#   u'particulier': 1,
#   u'remplier': 1,
#   u'sommer': 1},
#  u'dvse': {u'fiscalit\xe9': 1},
#  u'excellent': {u'enrichissant': 1,
#   u'environnement': 1,
#   u'formatrice': 1,
#   u'pertiner': 1},
#  u'b\xe2timent': {u'donner': 1},
#  u'agr\xe9able': {u'18h30': 1,
#   u'acqu\xe9rir': 1,
#   u'agence': 3,
#   u'ambiance': 3,
#   u'ann\xe9e': 1,
#   u'aspect': 1,
#   u'autre': 1,
#   u'beaucoup': 1,
#   u'cadre': 2,
#   u'cas': 1,
#   u'clier': 1,
#   u'collaborateur': 1,
#   u'condition': 1,
#   u'difficile': 1,
#   u'employ\xe9': 1,
#   u'environnement': 1,
#   u'fil': 1,
#   u'groupe': 1,
#   u'journ\xe9e': 1,
#   u'lad': 1,
#   u'management': 1,
#   u'manger': 1,
#   u'miser': 1,
#   u'nouveau': 1,
#   u'parfois': 1,
#   u'pouvoir': 1,
#   u'pression': 1,
#   u'remplir': 1,
#   u'rencontr\xe9re': 1,
#   u'r\xe9ussite': 1,
#   u'statut': 1,
#   u'surcharge': 1,
#   u'toujours': 1,
#   u'tous': 1,
#   u'travail': 4,
#   u'trier': 1,
#   u'trois': 1,
#   u'virement': 1,
#   u'\xe9volution': 2},
#  u'garantir': {u'diff\xe9rent': 1},
#  u'soutenir': {u'pariba': 1},
#  u'int\xe9ressant': {u'agr\xe9able': 1,
#   u'choses': 1,
#   u'perspectives': 1,
#   u'premier': 1,
#   u'\xe9quipe': 1},
#  u'garde': {u'tr\xe8s': 1},
#  u'\xe9quilibrer': {u'besoin': 1, u'travail': 1},
#  u'cas': {u'difficile': 1,
#   u'dire': 1,
#   u'pouvoir': 1,
#   u'prise': 1,
#   u'\xeatre': 1},
#  u'commentaire': {u'objectif': 1},
#  u'transparence': {u'communication': 1},
#  u'clients': {u'actualisation': 1,
#   u'agr\xe9able': 1,
#   u'aspect': 1,
#   u'canaux': 1,
#   u'carri\xe8re': 1,
#   u'client\xe8le': 1,
#   u'compte': 1,
#   u'conformit\xe9': 1,
#   u'conseil': 1,
#   u'consister': 1,
#   u'contact': 1,
#   u'd\xe9tection': 1,
#   u'gamme': 1,
#   u'gestion': 2,
#   u'g\xe9rer': 1,
#   u'immobilier': 2,
#   u'jour': 1,
#   u'management': 1,
#   u'performer': 1,
#   u'permettre': 1,
#   u'place': 1,
#   u'possible': 1,
#   u'poste': 2,
#   u'respecter': 1,
#   u'rester': 1,
#   u'servir': 1,
#   u'temps': 1,
#   u'tout': 1,
#   u'traitement': 1,
#   u'\xe9ch\xe9ance': 1,
#   u'\xe9quipe': 1,
#   u'\xeatre': 2},
#  u'focu': {u'equipe': 1},
#  u'formateur': {u'int\xe9rim': 1},
#  u'chang\xe9er': {u'form\xe9re': 1},
#  u'g\xe9rer': {u'5': 1,
#   u'appr\xe9ciable': 1,
#   u'autonome': 1,
#   u'clients': 1,
#   u'contrat': 1,
#   u'g\xe9n\xe9r\xe9er': 1},
#  u'falloir': {u'aussi': 1,
#   u'clients': 1,
#   u'management': 1,
#   u'poste': 1,
#   u'\xeatre': 1},
#  u'rangement': {u'signataire': 1},
#  u'encadrement': {u'br\xe8ve': 1},
#  u'cac': {u'mission': 1},
#  u'mondial': {u'euro': 1},
#  u'mouvement': {u'risque': 1},
#  u'consid\xe9r\xe9er': {u'entraide': 1},
#  u'apporteur': {u'mail': 1},
#  u'objectif': {u'agence': 1,
#   u'difficile': 1,
#   u'd\xe9crocher': 1,
#   u'd\xe9fi': 1,
#   u'organis\xe9er': 1,
#   u'permettre': 1,
#   u'sant\xe9': 1,
#   u'sortant': 1,
#   u'symbiose': 1,
#   u't\xe2che': 1},
#  u'challenging': {u'd\xe9but': 1},
#  u'climat': {u'\xe9volution': 1},
#  u'r\xe9el': {u'9000000': 1, u'prime': 1},
#  u'pont': {u'retour': 1},
#  u'dvop': {u'gestion': 1},
#  u'rythme': {u'gestion': 1, u'sein': 1},
#  u'honneur': {u'handicap\xe9': 1},
#  u'cardif': {u'alternance': 1,
#   u'immobilier': 1,
#   u'rencontres': 1,
#   u'\xe9norm\xe9ment': 1},
#  u'd\xe9fi': {u'\xe9quipe': 1},
#  u'mobilit\xe9': {u'emploi': 1, u'ouvrir': 1, u'\xeatre': 1},
#  u'quotidien': {u'collectif': 1,
#   u'commencer': 1,
#   u'exp\xe9riment\xe9': 1,
#   u'int\xe9resser': 1},
#  u'\xe9largir': {u'd\xe9couvrir': 1},
#  u'14h': {u'12h': 1, u'partir': 1},
#  u'joignable': {u'\xeatre': 1},
#  u'information': {u'agr\xe9able': 1,
#   u'colis': 1,
#   u'collecte': 1,
#   u'fiabilit\xe9': 1},
#  u'\xe9mission': {u'appel': 1},
#  u'flotter': {u'horaire': 1},
#  u'court': {u'pause': 1},
#  u'recenti': {u'points': 1},
#  u'ma\xeetrise': {u'cac': 1},
#  u'n\xe9gociation': {u'possibilit\xe9': 1},
#  u'six': {u'prendre': 1},
#  u'tableau': {u'person': 1},
#  u'apprenti': {u'stagiaire': 1},
#  u'rapport': {u'journ\xe9e': 1, u'pr\xe9cis\xe9ment': 1, u'visites': 1},
#  u'1': {u'6': 1, u'tous': 1},
#  u'optimiser': {u'agr\xe9able': 1},
#  u'varier': {u"'": 1,
#   u'analyse': 1,
#   u'avis': 1,
#   u'collaborateur': 1,
#   u'diversit\xe9': 1,
#   u'professionnel': 1,
#   u'travail': 1,
#   u'\xe9quipe': 1},
#  u'typique': {u';': 1, u'encadrer': 1, u'excel': 1, u'travail': 1},
#  u'\xe9clairage': {u'avenir': 1},
#  u'titre': {u'r\xe9aliser': 1},
#  u'proc\xe9dure': {u'compliqu\xe9er': 1, u'france': 1},
#  u'particulier': {u'op\xe9ration': 1, u'peut': 1, u'propos': 1, u'\xeatre': 1},
#  u'ensemble': {u'agr\xe9able': 1, u'repartir': 1},
#  u'interime': {u'poste': 1},
#  u's\xe9curisation': {u'pertinent': 1},
#  u'accorder': {u'\xeatre': 1},
#  u'fr': {u'\xe9volution': 1},
#  u'r\xe9union': {u'bien': 1, u'courtoise': 1, u'fois': 1},
#  u'plans': {u'convier': 1, u'fond': 1},
#  u'protection': {u'former': 1, u'multirisque': 1},
#  u'pr\xe9venir': {u'an': 1},
#  u'lad': {u'flux': 1},
#  u'attitrer': {u'etant': 1},
#  u'arr\xeat': {u'travailler': 1},
#  u'formare': {u'progresser': 1},
#  u'fiscalit\xe9': {u'devoir': 1, u'd\xe9positaire': 1},
#  u'b\xe9n\xe9ficier': {u'travailler': 1, u'vie': 1},
#  u'maximale': {u'sein': 1},
#  u'trier': {u'chose': 1},
#  u'entrer': {u'client': 1},
#  u'argentin': {u'bnp': 1},
#  u'moteur': {u'analyse': 1},
#  u'd\xe9battre': {u'collaborateur': 1},
#  u'date': {u'bleu': 1, u'\xe9quipe': 1},
#  u'heure': {u'b\xe9n\xe9ficier': 1,
#   u'\xe9lectronique': 1,
#   u'\xe9panouir': 1,
#   u'\xeatre': 1},
#  u'fr\xe9quent': {u'ainsi': 1},
#  u'types': {u'poste': 1},
#  u'cumuler': {u'flotter': 1},
#  u'sentir': {u'aspect': 1, u'important': 1, u'monde': 1},
#  u'trois': {u'banque': 1, u'intern': 1, u'travailler': 1},
#  u'dur\xe9e': {u'ainsi': 1, u'commercial': 1, u'mission': 1, u'pause': 1},
#  u'facile': {u'types': 1},
#  u'chef': {u'doute': 1, u'tous': 1},
#  u'organis\xe9er': {u'deux': 1, u'ressources': 1, u'tr\xe8s': 1},
#  u'conformit\xe9': {u'ma\xeetrise': 1, u'relation': 1},
#  u'trouver': {u'place': 1},
#  u'diversifi\xe9e': {u'gr\xe2ce': 1, u'transversal': 1},
#  u'st': {u'repas': 1},
#  u'enjeux': {u'transversalit\xe9': 1},
#  u'environ': {u'r\xe9sultat': 1},
#  u'favorablement': {u'client': 1},
#  u'client\xe8le': {u'commercial': 1,
#   u'occuper': 1,
#   u'ouverture': 1,
#   u'peu': 1,
#   u'pr\xe9paration': 1,
#   u'remplacement': 1,
#   u'tr\xe8s': 1,
#   u'utile': 1,
#   u'\xeatre': 1},
#  u'financement': {u'financier': 1},
#  u'documentaire': {u'flux': 1},
#  u'traducteur': {u'ainsi': 1, u'comit\xe9': 1, u'sein': 1},
#  u'exp\xe9riment\xe9': {u'financier': 1, u'vari\xe9er': 1},
#  u'mieux': {u'falloir': 1, u'permettre': 1, u'pr\xe9senter': 1, u'\xeatre': 1},
#  u'd\xe9biteur': {u'mieux': 1, u'morning': 1, u'mouvement': 1, u'typique': 1},
#  u'itm': {u'charge': 1},
#  u'synonyme': {u'sein': 1},
#  u'collectivement': {u'r\xe9union': 1},
#  u'jeun': {u'age': 1,
#   u'dysfonctionnement': 1,
#   u'introduire': 1,
#   u'organisation': 1,
#   u'participer': 1,
#   u'tr\xe8s': 1},
#  u'd\xe9positaire': {u'information': 1},
#  u'suffisamment': {u';': 1},
#  u'ordre': {u'cr\xe9ation': 1, u'\xe9norm\xe9ment': 1},
#  u'mission': {u'agr\xe9able': 1,
#   u'entreprise': 1,
#   u'modification': 1,
#   u'stage': 1,
#   u'travail': 2,
#   u'\xe9volution': 1,
#   u'\xeatre': 1},
#  u'peut': {u'difficult\xe9': 1},
#  u'clier': {u'mettre': 1, u'scanner': 1, u'travail': 1, u'\xeatre': 1},
#  u'attitude': {u'faire': 1},
#  u't\xe9l\xe9surveillance': {u'p24': 1},
#  u'signataire': {u'clients': 1},
#  u'spinoff': {u'dividende': 1},
#  u'r\xe9actif': {u'poste': 1},
#  u'd\xe9couvrir': {u'bnp': 2, u'changer': 1, u'commerce': 1},
#  u'famille': {u'tout': 1},
#  u'vite': {u'glorifiant': 1,
#   u'simulation': 1,
#   u'soci\xe9t\xe9': 1,
#   u'tr\xe8s': 1,
#   u'\xeatre': 1},
#  u'forc\xe9ment': {u'dessus': 1},
#  u'satisfaitre': {u'clients': 1},
#  u'\xe9co': {u'ch\xe8que': 1},
#  u'surtout': {u'mission': 1},
#  u'confi\xe9re': {u'incompr\xe9hension': 1},
#  u'organisation': {u'collaborateur': 1,
#   u'environnement': 1,
#   u'faire': 1,
#   u'grand': 1,
#   u'travailleur': 1,
#   u'\xeatre': 1},
#  u'int\xe9ress\xe9re': {u'heure': 1},
#  u'changement': {u'auto-formation': 1,
#   u'choses': 1,
#   u'd\xe9veloppement': 1,
#   u'international': 1},
#  u'vente': {u'besoin': 1, u'clients': 1, u'conseiller': 1, u'demander': 1},
#  u'termer': {u'savoir': 1},
#  u'coaching': {u'entreprise': 1},
#  u'primordial': {u'autonomie': 1, u'entente': 1},
#  u'choses': {u'apprendre': 1,
#   u'savoir': 1,
#   u'service': 1,
#   u'stage': 1,
#   u'strat\xe9gie': 1},
#  u'pr\xe9ser': {u'coll\xe8gue': 1, u'management': 1},
#  u'mail': {u'clients': 2,
#   u'propri\xe9taire': 1,
#   u'transmission': 1,
#   u'\xe9mission': 1},
#  u'"': {u'"': 1, u'culture': 1, u'leader': 1, u'march\xe9': 1},
#  u'main': {u'l\xe0': 1, u'r\xe9aliser': 1, u'\xe9quipe': 1},
#  u'fin': {u'aimer': 1,
#   u'concern\xe9e': 1,
#   u'fin': 1,
#   u'secret': 1,
#   u'tourn\xe9e': 1},
#  u'image': {u'int\xe9r\xeat': 1},
#  u'fil': {u'int\xe9resser': 1},
#  u'mettre': {u'administratif': 1,
#   u'administration': 1,
#   u'collaborateur': 2,
#   u'formare': 1,
#   u'globalit\xe9': 1,
#   u'pariba': 1,
#   u'pr\xe9parer': 1,
#   u'travail': 1,
#   u'tr\xe8s': 1},
#  u'refroidir': {u'environnement': 1},
#  u'difficult\xe9': {u'h\xe9siter': 1,
#   u'professionnel': 1,
#   u'sympathique': 1,
#   u'\xe9quipe': 1},
#  u'non': {u'bnp': 1, u'tous': 1},
#  u'savoir-faire': {u'vrai': 1},
#  u'int\xe9resser': {u'communication': 1,
#   u'convivialit\xe9': 1,
#   u'exp\xe9rience': 1,
#   u'grand': 1,
#   u'simple': 1,
#   u'temps': 1,
#   u'travail': 1},
#  u'diviser': {u'travail': 1},
#  u'equilibre': {u'forte': 1},
#  u'm\xe9contentement': {u'informatique': 1},
#  u'retrait': {u'ch\xe9quier': 1},
#  u'13h': {u'1h': 1, u'coupure': 1, u'dur\xe9e': 1},
#  u'conf\xe9rence': {u'pr\xe9voyance': 1},
#  u'apprendre': {u'entreprise': 2,
#   u'jamais': 1,
#   u'milieu': 1,
#   u'sentir': 1,
#   u'\xeatre': 2},
#  u'rigide': {u'constant': 1},
#  u'\xe9galement': {u'd\xe9couverte': 1, u'fermeture': 1},
#  u'badge': {u'accueil': 1},
#  u'ambition': {u'entreprise': 1},
#  u'superbe': {u'coll\xe8gue': 1},
#  u'obligatoire': {u'coh\xe9sion': 1},
#  u'provision': {u'r\xe9pondre': 1, u'vite': 1},
#  u'possibilit\xe9': {u'conseiller': 1,
#   u'employ\xe9': 1,
#   u'fran\xe7ais': 1,
#   u'hospitalisation': 1,
#   u'nombreux': 1,
#   u'outil': 1,
#   u'propos': 1,
#   u'pub': 1,
#   u'rien': 1,
#   u'stable': 1,
#   u'titre': 1,
#   u'\xeatre': 1},
#  u'hi\xe9rarchie': {u'4': 1, u'professionnel': 1, u'\xeatre': 1},
#  u'rencontres': {u'permettre': 1, u'tr\xe8s': 1},
#  u'faire': {u'20h': 1,
#   u'aimer': 1,
#   u'ch\xe8que': 2,
#   u'client\xe8le': 1,
#   u'concentrer': 1,
#   u'diff\xe9rent': 1,
#   u'humain': 1,
#   u'individuellement': 1,
#   u'int\xe9gration': 1,
#   u'jour': 1,
#   u'messagerie': 1,
#   u'primaut\xe9': 1,
#   u'principalement': 1,
#   u'profil': 1,
#   u'provision': 1,
#   u'rencontrer': 1,
#   u'sein': 1,
#   u'sujet': 1,
#   u'taches': 1,
#   u'tr\xe8s': 1,
#   u'\xe9chelle': 1,
#   u'\xeatre': 3},
#  u'cellule': {u'dernier': 1, u'tr\xe8s': 1},
#  u'embauche': {u'toujours': 1, u'\xe9volution': 1},
#  u'quartier': {u'plein': 1},
#  u'vouloir': {u'facile': 1, u'\xe9nergie': 1},
#  u'rigueur': {u'nouveau': 1, u'occuper': 1},
#  u'souvent': {u'collaborateur': 1, u'soucieux': 1},
#  u'transmission': {u'diff\xe9rent': 1},
#  u'18h30': {u'commencer': 1},
#  u'ann\xe9e': {u'client\xe8le': 1,
#   u'occuper': 1,
#   u'r\xe9mun\xe9ration': 1,
#   u'trop': 1},
#  u'm\xe9content': {u'difficile': 1, u'situation': 1},
#  u'clientele': {u'archivage': 1},
#  u'ma\xeetre': {u'\xeatre': 1},
#  u'rachetee': {u'connaissance': 1},
#  u'm&a': {u'faire': 1},
#  u'int\xe9gration': {u'environnement': 1, u'passer': 1},
#  u'donn\xe9e': {u'mise': 1},
#  u'ambiance': {u'aspect': 1,
#   u'aussi': 1,
#   u'autonomie': 1,
#   u'boulot': 1,
#   u'challenger': 1,
#   u'comp\xe9tent': 1,
#   u'demand\xe9er': 1,
#   u'deux': 1,
#   u'difficile': 1,
#   u'disponible': 1,
#   u'entrer': 1,
#   u'exprimer': 1,
#   u'exp\xe9rience': 1,
#   u'indispensable': 1,
#   u'management': 1,
#   u'manager': 1,
#   u'mission': 1,
#   u'person': 1,
#   u'produit': 1,
#   u'promotion': 1,
#   u'qualit\xe9': 1,
#   u'savoir': 1,
#   u'sup\xe9rieur': 1,
#   u'travail': 1,
#   u'tr\xe8s': 1,
#   u'\xeatre': 1},
#  u'avis': {u'agence': 1, u'comptable': 1, u'ost': 1, u'potentiel': 1},
#  u'organiser': {u'travail': 1},
#  u'autre': {u'cependant': 1,
#   u'connaitre': 1,
#   u'document': 1,
#   u'd\xe9velopper': 1,
#   u'fonction': 1,
#   u'int\xe9ressant': 1,
#   u'int\xe9resser': 1,
#   u'notamment': 1,
#   u'postes': 1,
#   u'principalement': 1,
#   u'r\xe9seau': 1,
#   u'traiter': 1},
#  u'challenger': {u'vie': 1},
#  u'interessement': {u'sentiment': 1},
#  u"y'er": {u'diversification': 1},
#  u'r\xe9seau': {u'moyen': 1, u'permettre': 1},
#  u'banal': {u'rendez-vous': 1},
#  u'requ\xeate': {u'pouvoir': 1},
#  u'd\xe9ontologique': {u'chiffre': 1},
#  u'entit\xe9': {u'directeur': 1},
#  u'initiatif': {u'\xe9quipe': 1},
#  u'rendez-vous': {u'autre': 1,
#   u'brief': 1,
#   u'journ\xe9e': 1,
#   u'occuper': 1,
#   u'suite': 1},
#  u'propri\xe9taire': {u'1000': 1},
#  u"'": {u"'": 1, u'diff\xe9rent': 1, u'temps': 1, u'vue': 1},
#  u'd\xe9but': {u'compliance': 1, u'qualit\xe9': 1},
#  u'statut': {u'place': 1},
#  u'responsabilit\xe9': {u'aboutir': 1, u'h\xf4tesse': 1, u'\xeatre': 1},
#  u'accueillant': {u'equipe': 1},
#  u'acteur': {u'exp\xe9riment\xe9er': 1},
#  u'toute': {u'enrichissant': 1, u'suivre': 1},
#  u'forte': {u'distinguer': 1, u'journ\xe9e': 1, u'\xeatre': 1},
#  u'anglophone': {u'traducteur': 1},
#  u'offre': {u'm\xe9tier': 1, u'\xeatre': 1},
#  u'effectu\xe9er': {u'formation': 1, u'toujours': 1},
#  u'maillon': {u'trop': 1},
#  u'retourner': {u'sein': 1},
#  u'remplacement': {u'\xeatre': 1},
#  u'd\xe9buter': {u'journ\xe9e': 1, u'signature': 1},
#  u'correct': {u'agence': 1, u'avantages': 1, u'cao': 1, u'salaire': 1},
#  u'inconv\xe9nient': {u'grosse': 1},
#  u'tomb\xe9es': {u'compte': 1},
#  u'8h': {u'quartier': 1, u'souhaiter': 1},
#  u'correcte': {u'equipe': 1},
#  u'dehors': {u'tous': 1},
#  u'workflow': {u'workflox': 1},
#  u'workflox': {u'documentaire': 1},
#  u'pr\xe9voyance': {u'bancaire': 1, u'niveau': 1},
#  u'pub': {u'indispensable': 1},
#  u'sain': {u'collaborateur': 1},
#  u'temps': {u'd\xe9ontologique': 1,
#   u'd\xe9pendre': 1,
#   u'entrepreneur': 1,
#   u'inclure': 1,
#   u'multiplicit\xe9': 1,
#   u'organisation': 1,
#   u'outil': 1,
#   u'redistribution': 1,
#   u'simple': 1,
#   u'tous': 1,
#   u'tr\xe8s': 1,
#   u't\xe2che': 2,
#   u'\xe9quilibrer': 1},
#  u'base': {u'savoir': 1},
#  u'formation': {u'atm': 1,
#   u'avantages': 1,
#   u'bnpp': 1,
#   u'collaborateur': 1,
#   u'd\xe9veloppement': 1,
#   u'entente': 1,
#   u'grand': 1,
#   u'groupe': 1,
#   u'lors': 1,
#   u'multi-culturelle': 1,
#   u'poste': 1,
#   u'pression': 1,
#   u'terme': 1,
#   u'terminer': 1,
#   u'\xe9couter': 1},
#  u'comprendre': {u'besoin': 1, u'commercial': 1, u'grand': 1, u'\xeatre': 1},
#  u'dire': {u'laquelle': 1, u'opportunit\xe9': 1},
#  u'livraison': {u'intervention': 1},
#  u'printemps': {u'organisation': 1},
#  u'ageable': {u'sein': 1},
#  u'all\xe9ger': {u'coll\xe8gue': 1, u'main': 1},
#  u'statistique': {u'tableau': 1},
#  u'demandeur': {u'administratif': 1},
#  u'am\xe9lioration': {u'cellule': 1},
#  u'chose': {u'collaborateur': 1},
#  u'rencontr\xe9e': {u'tr\xe8s': 1},
#  u'pr\xe9caire': {u'etc': 1},
#  u'100%': {u'opportunit\xe9': 1},
#  u'jeu': {u'rester': 1},
#  u'enfants': {u'personnel': 1},
#  u'ajouter': {u'experience': 1},
#  u'messagerie': {u'ticketing': 1},
#  u'v\xe9rification': {u'poste': 1, u'\uf0d8': 1},
#  u'place': {u'appel': 1,
#   u'aprimo': 1,
#   u'clients': 1,
#   u'complexe': 1,
#   u'respecter': 1,
#   u'salari\xe9': 1},
#  u'bilingue': {u'main': 1},
#  u'signature': {u'accompagnement': 1},
#  u'busines': {u'int\xe9grer': 1},
#  u'universit\xe9': {u'chiffre': 1},
#  u'form\xe9re': {u'\xeatre': 1},
#  u'indispensable': {u'constant': 1, u'\xeatre': 1},
#  u'lesquel': {u'\xeatre': 1},
#  u'1000': {u'lot': 1},
#  u'r\xe9sultat': {u'proximit\xe9': 1},
#  u'bleu': {u'virement': 1},
#  u'sp\xe9cifique': {u'calculon': 1},
#  u'classement': {u'tr\xe8s': 1},
#  u'permettre': {u'14h': 1,
#   u'ambiance': 1,
#   u'avancement': 1,
#   u'entreprise': 1,
#   u'etc': 1,
#   u'g\xe9r\xe9e': 1,
#   u'int\xe9ress\xe9re': 1,
#   u'possibilit\xe9': 1,
#   u'pr\xe9ser': 1,
#   u'rigueur': 1,
#   u'service': 1,
#   u'souple': 1,
#   u'travailler': 2,
#   u'\xe9change': 1,
#   u'\xeatre': 3},
#  u'ville': {u'situer': 1},
#  u'locataire': {u'800': 1},
#  u'logiciel': {u'coll\xe8gue': 1, u'travail': 2},
#  u'mise': {u'charger': 1, u'moteur': 1, u'prendre': 1},
#  u'ch\xe8que': {u'clients': 1, u'correct': 2, u't\xe2che': 1},
#  u'finance': {u'clients': 1},
#  u'extern': {u'mailing': 1, u'\xeatre': 1},
#  u'rendure': {u'relation': 1},
#  u'9000000': {u'direct': 1},
#  u'juriste': {u'bnp': 1},
#  u'habitation': {u'habitation': 1, u'produit': 1},
#  u'cantine': {u'avantages': 1, u'nombreux': 1},
#  u'ressentir': {u'\xeatre': 1},
#  u'r\xe9gularit\xe9': {u'clients': 1},
#  u'titres\u2026': {u'paiement': 1},
#  u'passer': {u'adaptation': 1, u'client': 1, u'employ\xe9': 1, u'part': 1},
#  u'aboutir': {u'gestion': 1},
#  u'management': {u'9h-17h': 1,
#   u'agr\xe9able': 1,
#   u'commercial': 1,
#   u'diff\xe9rent': 1,
#   u'doute': 1,
#   u'entit\xe9': 1,
#   u'groupe': 1,
#   u'livraison': 1,
#   u'mentoring': 1,
#   u'mission': 1,
#   u'opportunit\xe9': 1,
#   u'particulier': 1,
#   u'professionnel': 1,
#   u'qualit\xe9': 1,
#   u'recommander': 1,
#   u'rien': 1,
#   u'r\xe9alisation': 1,
#   u'travail': 1,
#   u'travailleur': 1,
#   u'trop': 1,
#   u'typique': 1,
#   u'\xab': 1,
#   u'\xe9largir': 1,
#   u'\xeatre': 4},
#  u'v\xe9ritablement': {u'chance': 1},
#  u'service': {u'clients': 1,
#   u'collaborateur': 1,
#   u'compte': 1,
#   u'confiance': 1,
#   u'connaissance': 1,
#   u'entreprise': 1,
#   u'esprit': 1,
#   u'excellent': 1,
#   u'garantir': 1,
#   u'gen': 1,
#   u'positif': 1,
#   u'possibilit\xe9': 1,
#   u'pouvoir': 1,
#   u'relationnel': 1,
#   u'requ\xe9rir': 1,
#   u'tr\xe8s': 1,
#   u'vacance': 1,
#   u'\xeatre': 1},
#  u'entr\xe9e': {u'aller': 1, u'suivi': 1},
#  u'portefeuille': {u'financier': 1, u'regarder': 1},
#  u'outre': {u'collaborateur': 1},
#  u'potentiel': {u'professionnel': 1},
#  u'bourse': {u'valeur': 1},
#  u'relations': {u'univers': 1},
#  u'laquelle': {u'difficile': 1},
#  u'terminer': {u'aller': 1, u'd\xe9marrer': 1, u'journ\xe9e': 1},
#  u'2': {u'conseiller': 1},
#  u'contr\xf4leur': {u'suffisamment': 1, u'tant': 1},
#  u'souci': {u'\xe9quipe': 1},
#  u'fmi': {u'participer': 1},
#  u'1h': {u'd\xe9jeuner': 1},
#  u'pote': {u'agr\xe9able': 1},
#  u'd\xe9passer': {u'atteindre': 1},
#  u'banque': {u'bnp': 1,
#   u'chaleureux': 1,
#   u'coeur': 1,
#   u'externe': 1,
#   u'financier': 1,
#   u'm\xe9tier': 1,
#   u'nombreux': 1,
#   u'occuper': 1,
#   u'valeur': 1},
#  u'plupart': {u'tous': 1},
#  u'contestation': {u'affectation': 1},
#  u'travail': {u'12h': 1,
#   u'accueil': 1,
#   u'agr\xe9able': 4,
#   u'aise': 2,
#   u'apprendre': 2,
#   u'apprentissage': 1,
#   u'aspect': 2,
#   u'augmenter': 1,
#   u'bien': 2,
#   u'bnp': 2,
#   u'building': 1,
#   u'chance': 1,
#   u'chef': 1,
#   u'coh\xe9sion': 1,
#   u'collaborateur': 1,
#   u'collaboration': 1,
#   u'coll\xe8gue': 1,
#   u'commentaire': 1,
#   u'commercial': 1,
#   u'communication': 1,
#   u'contrat': 1,
#   u'cr\xe9er': 1,
#   u'domaine': 1,
#   u'dynamique': 1,
#   u'dysfonctionnement': 1,
#   u'e-mail': 1,
#   u'employer': 1,
#   u'encadrement': 1,
#   u'enrichissant': 1,
#   u'entente': 1,
#   u'entier': 1,
#   u'entreprise': 1,
#   u'environnement': 1,
#   u'exp\xe9rience': 1,
#   u'favorable': 1,
#   u'fonctionnel': 1,
#   u'formateur': 1,
#   u'information': 1,
#   u'interaction': 1,
#   u'int\xe9ressant': 1,
#   u'int\xe9resser': 1,
#   u'joinville': 1,
#   u'journ\xe9e': 1,
#   u'laisser': 1,
#   u'logiciel': 1,
#   u'mobilit\xe9': 1,
#   u'nombreux': 1,
#   u'organis\xe9er': 1,
#   u'place': 1,
#   u'positif': 1,
#   u'poste': 1,
#   u'pouvoir': 3,
#   u'premi\xe8re': 1,
#   u'professionnel': 1,
#   u'projet': 1,
#   u'prospectif': 1,
#   u'qualifier': 1,
#   u'qualit\xe9': 1,
#   u'ranger': 1,
#   u'rapide': 1,
#   u'r\xe9gulier': 1,
#   u'r\xe9seau': 1,
#   u'sain': 1,
#   u'scolaire': 1,
#   u'sourire': 1,
#   u'suite': 1,
#   u'temps': 1,
#   u'tr\xe8s': 3,
#   u'vrai': 1,
#   u'vraiment': 1,
#   u'\xe9couter': 1,
#   u'\xe9quipe': 1,
#   u'\xeatre': 1},
#  u'ainsi': {u'accueil': 1,
#   u'client': 1,
#   u'contact': 2,
#   u'contr\xf4le': 1,
#   u'effectuer': 1,
#   u'envie': 1,
#   u'fiscalit\xe9': 1,
#   u'intern': 1,
#   u'rentabilit\xe9': 1,
#   u'r\xe9ception': 1,
#   u'soci\xe9t\xe9': 1,
#   u'\xeatre': 2},
#  u'17h': {u'd\xe9buter': 2},
#  u'patron': {u'conseil': 1},
#  u'escalader': {u'incident': 1},
#  u'ennuyer': {u'assez': 1},
#  u'fiabilit\xe9': {u'entr\xe9e': 1, u'risque': 1},
#  u'multi-culturelle': {u'd\xe9couverte': 1},
#  u'sociable': {u'collaborateur': 1},
#  u'55an': {u'\xeatre': 1},
#  u'avanc\xe9': {u'rendre': 1},
#  u'part': {u'finalement': 1,
#   u'int\xe9rimaire': 1,
#   u'tout': 1,
#   u'\xe9volution': 1,
#   u'\xeatre': 2},
#  u'permanent': {u'assurance': 1, u'prendre': 1, u'sympathique': 1},
#  u'favorable': {u'\xe9quipe': 1},
#  u'situer': {u'bnp': 1},
#  u'atteindre': {u'pr\xeate': 1},
#  u'entente': {u'beaucoup': 1, u'devoir': 1, u'int\xe9resser': 1, u'tant': 1},
#  u'maintenir': {u'mener': 1, u'ressources': 1},
#  u'antin': {u'travailler': 1},
#  u'institution': {u'enrichissant': 1},
#  u'produit': {u'agence': 1,
#   u'aussi': 1,
#   u'bnp': 1,
#   u'commercial': 1,
#   u'coter': 1,
#   u'prospect': 1,
#   u't\xe2che': 1,
#   u'\xe9pargne': 1,
#   u'\xe9tude': 1},
#  u'prendre': {u'bnp': 1,
#   u'diff\xe9rent': 1,
#   u'd\xe9partement': 1,
#   u'pariba': 1,
#   u'retrait': 1,
#   u'travail': 1},
#  u'gen\xe8ve': {u'entretenure': 1},
#  u'disposer': {u'\xeatre': 1},
#  u'plein': {u'parer': 1, u'pariba': 1, u'r\xe9aliser': 1, u'tant': 1},
#  u'bel': {u'journ\xe9e': 1, u'universit\xe9': 1, u'\xeatre': 1},
#  u'p24': {u'assurance': 1},
#  u'dossier': {u'analyse': 1,
#   u'poste': 1,
#   u'savoir': 1,
#   u'service': 1,
#   u'\xe9galement': 1,
#   u'\xeatre': 1},
#  u'dialogue': {u'individuel': 1},
#  u'visites': {u'renouvellement': 1},
#  u'notamment': {u'op\xe9ration': 1, u'texte': 1},
#  u'juridique': {u'am\xe9lioration': 1,
#   u'assurer': 1,
#   u'comprendre': 1,
#   u'intervenir': 1},
#  u'classer': {u'accueillir': 1},
#  u'entenduer': {u'gentil': 1},
#  u'pr\xe9paration': {u'former': 1, u'service': 1, u'suivre': 1},
#  u'matin\xe9e': {u'reunir': 1},
#  u'gestion': {u'accompagner': 1,
#   u'actuariat': 1,
#   u'an': 1,
#   u'aspect': 1,
#   u'collaborateur': 1,
#   u'commercial': 1,
#   u'composer': 1,
#   u'd\xe9biteur': 1,
#   u'd\xe9velopper': 1,
#   u'entreprise': 1,
#   u'environ': 1,
#   u'envoi': 1,
#   u'esprit': 1,
#   u'ex\xe9cution': 1,
#   u'financier': 1,
#   u'interm\xe9diaire': 1,
#   u'intervenir': 1,
#   u'journ\xe9e': 1,
#   u'moyens': 1,
#   u'pression': 1,
#   u'r\xe9\xe7ue': 1,
#   u'terme': 1,
#   u't\xe9l\xe9phonique': 1,
#   u't\xeate': 1,
#   u'xml': 1},
#  u'consister': {u'traduction': 1, u'\xe9tat': 1},
#  u'constructif': {u'management': 1},
#  u'alternance': {u'2': 1, u'formation': 1, u'milieu': 1, u'\xeatre': 2},
#  u'capitalistique': {u'traduction': 1},
#  u'recevoir': {u'administratif': 1},
#  u'prospect': {u'r\xe9ception': 1},
#  u'courte': {u'\xe9tude': 1},
#  u'rad': {u'gestion': 1},
#  u'aff\xe9rent': {u'clients': 1},
#  u'effet': {u'"': 1},
#  u'aller': {u'gestion': 1, u'remplier': 1},
#  u'porte-feuille': {u'rendez-vous': 1},
#  u'attractif': {u'client': 1},
#  u'march\xe9re': {u'baisse': 1},
#  u'pro': {u'professionnel': 1},
#  u'premier': {u'coaching': 1,
#   u'exp\xe9rience': 1,
#   u'tr\xe8s': 1,
#   u'workflow': 1},
#  u'qualit\xe9': {u'effectuer': 1,
#   u'etc': 1,
#   u'formation': 1,
#   u'n\xe9cessaire': 1,
#   u'quotidien': 1,
#   u'respecter': 1,
#   u'sein': 1},
#  u'longu': {u'choses': 1, u'interne': 1},
#  u'individuel': {u'objectif': 1},
#  u'direct': {u'agr\xe9able': 1, u'\xe9ch\xe9ancier': 1},
#  u'exercer': {u'd\xe9cision': 1},
#  u'cong\xe9': {u'st': 1},
#  u'financier': {u'adapter': 1,
#   u'analyse': 1,
#   u'contr\xf4leur': 1,
#   u'diff\xe9rent': 1,
#   u'fr': 1,
#   u'pariba': 1,
#   u'respect': 1,
#   u'varier': 1,
#   u'vente': 1,
#   u'\xeatre': 1},
#  u'individuellement': {u'objectif': 1},
#  u'20h': {u'14h': 1},
#  u'concentration': {u'environnement': 1},
#  u'etre': {u'loin': 1},
#  u'incompr\xe9hension': {u'tr\xe8s': 1},
#  u'salaire': {u'logiciel': 1, u'respect': 1},
#  u'jour': {u'pariba': 1,
#   u'pr\xe9venir': 1,
#   u'pr\xeat': 1,
#   u'traitement': 1,
#   u'vente': 1,
#   u'\xe9co': 1},
#  u'\xe9ventuel': {u'juridique': 1},
#  u'atm': {u'gestion': 1},
#  u'apercevoir': {u'job': 1},
#  u'alors': {u'apprendre': 1, u'plaindre': 1},
#  u'physique': {u'venir': 1},
#  u'building': {u'd\xe9partement': 1},
#  u'valeur': {u'coop\xe9ration': 1,
#   u'diff\xe9rent': 1,
#   u'g\xe9n\xe9ration': 1,
#   u'pouvoir': 1},
#  u'exister': {u'd\xe9veloppement': 1},
#  u'handicap\xe9': {u'salaire': 1},
#  u'contact': {u'*': 1,
#   u'accomplir': 1,
#   u'aspect': 2,
#   u'fournir': 1,
#   u'journ\xe9e': 1,
#   u'm\xe9tier': 1,
#   u'poste': 1,
#   u'sen': 1,
#   u'travail': 2,
#   u'travailler': 1,
#   u'\xe9tendre': 1},
#  u'tarifaire': {u'cantine': 1},
#  u'forces': {u'centre': 1},
#  u'agence': {u'1': 1,
#   u'accueil': 1,
#   u'autre': 2,
#   u'bnp': 1,
#   u'collectivement': 1,
#   u'contact': 1,
#   u'court': 1,
#   u'directeur': 1,
#   u'discuter': 1,
#   u'juger': 1,
#   u'moins': 1,
#   u'plaisante': 1,
#   u'plut\xf4t': 1,
#   u'poste': 1,
#   u'pouvoir': 1,
#   u'terme': 1,
#   u'travailler': 1,
#   u'\xe9quipe': 1,
#   u'\xeatre': 1},
#  u'65': {u'extern': 1},
#  u'apparenter': {u'cergy': 1},
#  u'br\xe8ve': {u'exp\xe9rience': 1},
#  u'suivi': {u'direct': 1, u'immobilier': 1, u'r\xe9f\xe9rentiel': 1},
#  u'dernier': {u'\xe9ventuel': 1},
#  u'tarificatrice': {u'jeu': 1},
#  u'\xe9tendre': {u'r\xe9guli\xe8rement': 1},
#  u'regard': {u'contact': 1},
#  u'am\xe9liorer': {u'gentil': 1, u'point': 1},
#  u'normal': {u'exp\xe9rience': 1},
#  u'grandir': {u'vari\xe9t\xe9': 1},
#  u't\xe2che': {u'actuellement': 1,
#   u'ainsi': 1,
#   u'all\xe9ger': 1,
#   u'chef': 1,
#   u'longu': 1,
#   u'ma\xeetre': 1,
#   u'officer': 1,
#   u'peu': 1,
#   u'point': 1,
#   u'seul': 1,
#   u'vente': 1,
#   u'vite': 1,
#   u'\xeatre': 1},
#  u'collaboration': {u'bas\xe9er': 1,
#   u'clients': 1,
#   u'renduer': 1,
#   u'\xe9quipe': 1},
#  u'etant': {u'beaucoup': 1},
#  u'numero': {u'hierarchie': 1},
#  u'concern\xe9e': {u'information': 1},
#  u'quelqu': {u'entraider': 1},
#  u'accomplir': {u't\xe2che': 1},
#  u'\xe9tat': {u'assurer': 1, u'jeun': 1},
#  u'plan': {u'comp\xe9tent': 1,
#   u'exp\xe9rience': 1,
#   u'longu': 1,
#   u'point': 1,
#   u'\xeatre': 1},
#  u'plaindre': {u'clients': 1},
#  u'auxiliaire': {u'degr\xe9': 1},
#  u'grave': {u'am\xe9rique': 1},
#  u'ticketing': {u'priser': 1},
#  u'toutefois': {u'formation': 1},
#  u'renseignement': {u'aupr\xe8s': 1},
#  u'urgence': {u'poste': 1},
#  u'800': {u'gestion': 1},
#  u'placement': {u'adapt\xe9er': 1, u'ainsi': 1},
#  u'ailleurs': {u'occuper': 1},
#  u'montage': {u'produit': 1},
#  u'bref': {u't\xe9l\xe9phone': 1},
#  u'fier': {u'collaborateur': 1},
#  u'prof\xe9ssionnel': {u'groupe': 1},
#  u'face': {u'recevoir': 1, u't\xe9l\xe9phone': 1, u'vite': 1},
#  u'g\xe9r\xe9e': {u'comprendre': 1},
#  u'scolaire': {u'travail': 1},
#  u'contr\xf4le': {u'domaine': 1, u'donn\xe9e': 1},
#  u'ouverture': {u'caf\xe9': 1, u'fond': 1, u'travail': 1, u'\xeatre': 1},
#  u'comit\xe9': {u'autre': 1},
#  u's\xe9rieux': {u'travail': 1},
#  u'r\xe9alisation': {u'4': 1, u'bancaire': 1, u'collaborateur': 1},
#  u'mailing': {u'effectuer': 1},
#  u'compliqu\xe9er': {u'accueil': 1, u'permettre': 1},
#  u'fermeture': {u'banque': 1, u'relation': 1, u'reprendre': 1},
#  u'scrupuleusement': {u'pariba': 1},
#  u'cdd': {u'concerner': 1,
#   u'professionnel': 1,
#   u'pr\xe9caire': 1,
#   u'stage': 1},
#  u'symbiose': {u'pro': 1},
#  u'officer': {u'apercevoir': 1},
#  u'montr\xe9re': {u'agr\xe9able': 1},
#  u'coeur': {u'gen\xe8ve': 1},
#  u'12h': {u'petit': 1, u'\xeatre': 1},
#  u'interdiction': {u'motiv\xe9': 1},
#  u'fois': {u'autre': 1, u'jusque': 1},
#  u'fond': {u'appui': 1, u'fonds': 1},
#  u'vacance': {u'exp\xe9rience': 1},
#  u'produire': {u'tranquillit\xe9': 1},
#  u'toujours': {u'chance': 1,
#   u'coll\xe8gue': 1,
#   u'difficile': 1,
#   u'famille': 1,
#   u'objectif': 1,
#   u'ouvrir': 1,
#   u'pariba': 1,
#   u'p\xf4le': 1,
#   u'quotidien': 1,
#   u'salari\xe9': 1,
#   u'tr\xe8s': 3,
#   u'utile': 1,
#   u'\xe9couter': 1,
#   u'\xe9volution': 1},
#  u'd\xe9faut': {u'temps': 1},
#  u'relation': {u'aise': 1,
#   u'aspect': 1,
#   u'niveau': 1,
#   u'ouverture': 1,
#   u'r\xe9gularit\xe9': 1},
#  u'exp\xe9riment\xe9er': {u'pariba': 1},
#  u'trop': {u'avis': 1,
#   u'efficacement': 1,
#   u'niveau': 1,
#   u'plupart': 1,
#   u'possible': 1,
#   u'r\xe9pondre': 1},
#  u'hierarchie': {u'employ\xe9': 1},
#  u'interm\xe9diaire': {u'exp\xe9rience': 1},
#  u'principal': {u'aff\xe9rent': 1, u'faire': 1, u'\xeatre': 1},
#  u'xml': {u'correcte': 1},
#  u'pnb': {u'solution': 1},
#  u'b\xe9mol': {u'r\xe9el': 1},
#  u'r\xe9aliser': {u'code': 1,
#   u'm\xe9content': 1,
#   u'place': 1,
#   u'positif': 1,
#   u'relance': 1},
#  u'entrepreneur': {u'diff\xe9rent': 1},
#  u'zone': {u'bancaire': 1},
#  u'attente': {u'rendre': 1},
#  u'vari\xe9t\xe9': {u'permettre': 1},
#  u'collecte': {u'\xe9tablissement': 1},
#  u'bien': {u'ambiance': 1,
#   u'collaborateur': 1,
#   u'coll\xe8gue': 1,
#   u'courant': 1,
#   u'entreprise': 1,
#   u'exp\xe9rience': 1,
#   u'f\xe9d\xe9rateur': 1,
#   u'manager': 1,
#   u'nouveau': 1,
#   u'pme': 1,
#   u'six': 1,
#   u'travail': 1,
#   u'\xeatre': 1},
#  u'rentabilit\xe9': {u'sp\xe9cifique': 1},
#  u'employer': {u'tr\xe8s': 1},
#  u'rendre': {u'effectuer': 1,
#   u'intensif': 1,
#   u'mise': 1,
#   u'relativement': 1,
#   u'retour': 1,
#   u'\xe9couter': 1},
#  u'formatrice': {u'\xeatre': 1},
#  u'tutelle': {u'pariba': 1},
#  u'plaire': {u'accueil': 1, u'tous': 1, u'\xeatre': 1},
#  u'diff\xe9rent': {u'1': 1,
#   u'acqu\xe9rir': 1,
#   u'assez': 1,
#   u'avantages': 1,
#   u'baser': 1,
#   u'cadre': 1,
#   u'clients': 1,
#   u'client\xe8le': 1,
#   u'collaboration': 1,
#   u'compliance': 1,
#   u'nouveau': 1,
#   u'occuper': 1,
#   u'relation': 1,
#   u'rencontr\xe9e': 1,
#   u'responsable': 1,
#   u'toute': 1,
#   u'toutes': 1,
#   u'travail': 1,
#   u'travailler': 1,
#   u't\xe9l\xe9phonique': 1},
#  u'cependant': {u'alternance': 1,
#   u'management': 1,
#   u'paisible': 1,
#   u'pression': 1,
#   u'\xeatre': 2},
#  u'employee': {u'entreprise': 1},
#  u'8': {u'clientele': 1, u'confi\xe9re': 1},
#  u'acqu\xe9rir': {u'permettre': 1, u'petit': 1, u'sen': 1, u'travailler': 1},
#  u'reporting': {u'produit': 1},
#  u'dysfonctionnement': {u'mettre': 1, u'occuper': 1},
#  u'administratif': {u'commercial': 2, u'produit': 1, u'r\xe9ception': 1},
#  u'les': {u'diff\xe9rent': 1},
#  u'distance': {u'assistance': 1, u't\xe9l\xe9phonique': 1},
#  u'\xe9panouissement': {u'travail': 1},
#  u'\xe9gal': {u'repartier': 1},
#  u're\xe7uer': {u'donner': 1},
#  u'monde': {u'collaborateur': 1,
#   u'coll\xe8gue': 1,
#   u'commercial': 1,
#   u'entreprise': 1,
#   u'exp\xe9rience': 1,
#   u'premi\xe8re': 1,
#   u'satisfaisant': 1,
#   u'stagiaire': 1,
#   u'\xe9volution': 1},
#  u'pr\xeat': {u'collaborateur': 1, u'\xe9tat': 1},
#  u'actions': {u'investissement': 1},
#  u'passionnant': {u'commencer': 1},
#  u'int\xe9r\xeat': {u'proposition': 1, u'savoir': 1},
#  u'gen': {u'aimer': 1},
#  u'dure': {u'rendre': 1},
#  u'\xe2ge': {u'r\xe9pondre': 1},
#  u'nouveau': {u'challenge': 1, u'professionnel': 1, u'\xeatre': 3},
#  u'crier': {u'm\xe9content': 1},
#  u'evolution': {u'ambiance': 1, u'mobilit\xe9': 1, u'partie': 1},
#  u'transversal': {u'occuper': 1},
#  u'boulot': {u'caf\xe9': 1},
#  u'partie': {u'beaucoup': 1},
#  u'h': {u'dur\xe9e': 1, u'priser': 1},
#  u'compos\xe9er': {u'pariba': 1},
#  u'morning': {u'journ\xe9e': 1},
#  u'partir': {u'fois': 1, u'vraiment': 1, u'\xeatre': 1},
#  u'arriv\xe9e': {u'client': 1, u'pleinement': 1},
#  u'\xe9vidence': {u'etats-uni': 1},
#  u'horaire': {u'beaucoup': 1,
#   u'coh\xe9sion': 1,
#   u'graphique': 1,
#   u'g\xe9rer': 1,
#   u'incontournable': 1,
#   u'travail': 1},
#  u'tourner': {u'ambition': 1},
#  u'premi\xe8re': {u'bnp': 1, u'conseil': 1},
#  u'x': {u'r\xe9pondre': 1},
#  u'implication': {u'exceptionnel': 1},
#  u'graphique': {u'diff\xe9rent': 1},
#  u'accueillir': {u'conseiller': 1,
#   u'effectu\xe9er': 1,
#   u'strict': 1,
#   u'travail': 1,
#   u'\xeatre': 1},
#  u'vision': {u'situation': 1},
#  u'f\xeate': {u'souvent': 1},
#  u'manger': {u'arriver': 1, u'pause': 1},
#  u'd\xe9marchage': {u'appel': 1},
#  u'\xe9change': {u'aspect': 1, u'conduiter': 1},
#  u'jusque': {u'entr\xe9e': 1, u'journ\xe9e': 1, u'personnel': 1},
#  u'dynamique': {u'efforcer': 1, u'tr\xe8s': 1, u'\xeatre': 1},
#  u'raison': {u'favorablement': 1},
#  u'paisible': {u'contribuer': 1},
#  u'job': {u'bien': 1, u'possibilit\xe9': 1},
#  u'priser': {u'beaucoup': 1,
#   u'comptable': 1,
#   u'pouvoir': 1,
#   u'premier': 1,
#   u'taches': 1},
#  u'critiquable': {u'succursal': 1},
#  u'libre': {u'travail': 1},
#  u'n\xe9cessaire': {u'comprendre': 1, u'regard': 1, u'r\xf4le': 1},
#  u'grosse': {u'attractif': 1, u'courant': 1},
#  u'culture': {u'assez': 1, u'collectif': 1, u'credit': 1, u'priv\xe9er': 1},
#  u'professionnel': {u'*': 1,
#   u'autant': 1,
#   u'compos\xe9er': 1,
#   u'conseiller': 1,
#   u'consid\xe9ration': 1,
#   u'dure': 1,
#   u'employee': 1,
#   u'enrichissant': 1,
#   u'exp\xe9rience': 1,
#   u'faible': 1,
#   u'matin\xe9e': 1,
#   u'objectif': 1,
#   u'permettre': 1,
#   u'personnel': 1,
#   u'poste': 1,
#   u'vie': 1,
#   u'\xe9norm\xe9ment': 1,
#   u'\xe9voluer': 1},
#  u'irr\xe9prochable': {u'postes': 1},
#  u'al\xe9atoire': {u'varier': 1},
#  u'alternant': {u'pouvoir': 1},
#  u'sen': {u'alternance': 1, u'ann\xe9e': 1, u'demander': 1},
#  u'matin': {u'bnp': 1},
#  u'sp\xe9cialis\xe9er': {u'actuariat': 1},
#  u'arm': {u'quotidien': 1},
#  u'points': {u'faire': 1},
#  u'effectuer': {u'discuter': 1,
#   u'd\xe9livrer': 1,
#   u'esprit': 1,
#   u'ponctuellement': 1,
#   u'tr\xe8s': 1,
#   u'tr\xe9': 1,
#   u'tuteur': 1,
#   u'\xeatre': 2},
#  u'secr\xe9tariat': {u'accueil': 1},
#  u'encore': {u'donner': 1, u'entreprise': 1},
#  u'expert': {u'notamment': 1},
#  u'prononc\xe9er': {u'sanction': 1},
#  u'irp': {u'ambiance': 1},
#  u'notaire': {u'clients': 1},
#  u'concertation': {u'\xe9voluer': 1},
#  u'mod\xe8le': {u'angler': 1},
#  u'pousser': {u'effectif': 1, u'manager': 1},
#  u'lotu': {u'itm': 1},
#  u'ordinateur': {u'outil': 1},
#  u'3': {u'avantages': 1,
#   u'changement': 1,
#   u'r\xe9gulier': 1,
#   u'\xe9couter': 1},
#  u'occasion': {u'poste': 1},
#  u'bureau': {u'achever': 1, u'ambiance': 1},
#  u'\xe9norm\xe9ment': {u'jeun': 1,
#   u'jour': 1,
#   u'traduction': 1,
#   u'travail': 1,
#   u'\xeatre': 3},
#  u'ex\xe9cution': {u'prendre': 1, u'rapport': 1, u'sentir': 1},
#  u'it': {u'back': 1},
#  u'motivant': {u'initiatif': 1},
#  u'r\xe9ception': {u'8': 1,
#   u'apporteur': 1,
#   u'archivage': 1,
#   u'bien': 1,
#   u'gestion': 1,
#   u'temps': 1},
#  u'canaux': {u'difficile': 1},
#  u'360': {u'difficile': 1},
#  u'd\xe9crocher': {u'heure': 1},
#  u'redire': {u'niveau': 1},
#  u'professionel': {u'dur': 1},
#  u'17an': {u'exp\xe9rience': 1},
#  u'reguler': {u'd\xe9veloppement': 1},
#  u'scanning': {u'refroidir': 1},
#  u'derni\xe8re': {u'\xeatre': 1},
#  u'satisfaisant': {u'travail': 1},
#  u'attention': {u'salari\xe9': 1},
#  u'bilan': {u'management': 1},
#  u'exercice': {u'ambitieux': 1},
#  u'math\xe9matique': {u'question': 1},
#  u'transmettre': {u'talentueux': 1},
#  u'incident': {u'ainsi': 1},
#  u'mentoring': {u'opportunit\xe9': 1},
#  u'parfaitement': {u'enfants': 1},
#  u'incivilit\xe9': {u'difficile': 1},
#  u'traduction': {u'agr\xe9able': 1, u'\xeatre': 2},
#  u'configuration': {u'distance': 1},
#  u'ind\xe9niablement': {u'poste': 1},
#  u'vrai': {u'permettre': 1, u'tutelle': 1},
#  u'dividende': {u'\uf0d8': 1},
#  u'p\xf4le': {u'd\xe9tail': 1, u'escalader': 1},
#  u'recherche': {u'poste': 1},
#  u'vue': {u'enrichissant': 1, u'long': 1, u'management': 1},
#  u'candidat': {u'\xeatre': 1},
#  u'h\xf4tesse': {u'aise': 1},
#  u'optimisation': {u'phoning': 1},
#  u'adapter': {u'difficile': 1, u'opportunit\xe9': 1},
#  u'politique': {u'bnp': 1, u'opportunit\xe9': 1, u'\xeatre': 1},
#  u'entraide': {u'travail': 1, u'\xeatre': 1},
#  u'terme': {u'perspectif': 1, u'r\xe9union': 1, u'vision': 1},
#  u'veiller': {u'bnp': 1, u'personnel': 1},
#  u'transversalit\xe9': {u'challenging': 1},
#  u'etc': {u'compte': 1,
#   u'gestion': 1,
#   u'logistique': 1,
#   u'service': 1,
#   u'\xe9change': 1},
#  u'tous': {u'bnp': 1,
#   u'commercial': 1,
#   u'disponible': 1,
#   u'etc': 1,
#   u'matin': 1,
#   u'moment': 1,
#   u'opportunit\xe9': 1,
#   u'pariba': 1,
#   u'pause': 1,
#   u'rendez-vous': 1,
#   u'travail': 1,
#   u'tri': 1,
#   u'tr\xe8s': 1,
#   u'\xe9volution': 1,
#   u'\xeatre': 1},
#  u'tout': {u'*': 1,
#   u'capitalistique': 1,
#   u'entreprise': 1,
#   u'faire': 1,
#   u'partiel': 1,
#   u'possibilit\xe9': 1,
#   u'sept': 1,
#   u'traducteur': 1,
#   u'tr\xe8s': 1,
#   u'\xeatre': 2},
#  u'figurer': {u'mondial': 1},
#  u'vraiment': {u'campagne': 1, u'contact': 1, u'encodage': 1},
#  u'demander': {u'colis': 1, u'd\xe9passer': 1, u'\xe9couter': 1},
#  u'calculon': {u'rachat': 1},
#  u'pr\xe9cis': {u'poste': 1},
#  u'd\xe9finie': {u'traiter': 1},
#  u'autour': {u'voir': 1},
#  u'bnp': {u'13h': 1,
#   u'ageable': 1,
#   u'application': 1,
#   u'avanc\xe9': 1,
#   u'badge': 1,
#   u'bases': 1,
#   u'campagne': 1,
#   u'commercial': 1,
#   u'coordonn\xe9e': 1,
#   u'excellent': 1,
#   u'faible': 1,
#   u'faire': 2,
#   u'fin': 1,
#   u'honneur': 1,
#   u'int\xe9ressant': 1,
#   u'leader': 1,
#   u'local': 1,
#   u'mois': 1,
#   u'nouvel': 1,
#   u'opportunit\xe9': 1,
#   u'ordre': 1,
#   u'outre': 1,
#   u'satisfaire': 1,
#   u'service': 1,
#   u'\xe9couter': 1,
#   u'\xe9quipe': 3,
#   u'\xe9volution': 1,
#   u'\xeatre': 1},
#  u'moa': {u'travail': 1},
#  u'point': {u'directeur': 1,
#   u'partir': 1,
#   u'salari\xe9': 1,
#   u'vari\xe9er': 1,
#   u'venir': 1,
#   u'\xeatre': 1},
#  u'simple': {u'permettre': 1, u'soci\xe8t\xe9': 1, u'\xeatre': 1},
#  u'comp\xe9tition': {u'ambiance': 1},
#  u'dimension': {u'x': 1},
#  u'moyenne': {u'irp': 1, u'service': 1},
#  u'motivation': {u'certes': 1},
#  u'adapt\xe9er': {u'agr\xe9able': 1, u'orienter': 1},
#  u'r\xe9\xe7ue': {u'v\xe9rification': 1},
#  u'juger': {u'periode': 1},
#  u'\xe9quilibre': {u'\xeatre': 1},
#  u'adaptation': {u'agr\xe9able': 1, u'clients': 1},
#  u'contrat': {u'bel': 1, u'compte-rendu': 1, u'\xeatre': 2},
#  u'traitement': {u'17h': 1,
#   u'apprenti': 1,
#   u'client\xe8le': 1,
#   u'dvop': 1,
#   u'gestion': 1,
#   u'op\xe9ration': 1},
#  u'constamment': {u'complexe': 1},
#  u'responsable': {u'confiance': 1,
#   u'corporate': 1,
#   u'groupe': 1,
#   u'pariba': 1},
#  u'nicola': {u'ch\xe8que': 1},
#  u'seulement': {u'pariba': 1},
#  u'exigeant': {u'atmosph\xe8re': 1, u'clients': 1},
#  u'scanner': {u'simple': 1},
#  u'moins': {u'collaborateur': 1,
#   u'commercial': 1,
#   u'conseil': 1,
#   u'travail': 1},
#  u'19h00': {u'06h45': 1},
#  u'lesquelle': {u'bancaire': 1},
#  u'perspectives': {u'optimisation': 1, u'\xeatre': 1},
#  u'coh\xe9rent': {u'firme': 1},
#  u'reunir': {u'arriver': 1},
#  u'd\xe9saccord': {u'rapidement': 1},
#  u'convenablement': {u'politique': 1},
#  u'avancement': {u'tr\xe8s': 1},
#  u'milieu': {u'offrir': 1, u'permis': 1},
#  u'prime': {u'soci\xe9t\xe9': 1},
#  u'secret': {u'd\xe9battre': 1},
#  u'tuteur': {u'accompagnement': 1},
#  u'interne': {u'b\xe9mol': 1, u'd\xe9veloppement': 1, u'r\xe9ceptionner': 1},
#  u'd\xe9cision': {u'enjeux': 1, u'ignor\xe9er': 1, u'juridique': 1},
#  u'equipe': {u'beaucoup': 1, u'plan': 1, u'pnb': 1},
#  u'collaborateur': {u'agr\xe9able': 1,
#   u'ambiance': 2,
#   u'aspect': 1,
#   u'assurer': 1,
#   u'chance': 1,
#   u'commercial': 1,
#   u'comp\xe9tent': 1,
#   u'correspondre': 1,
#   u'diff\xe9rent': 1,
#   u'd\xe9jeuner': 1,
#   u'd\xe9velopper': 1,
#   u'entreprise': 1,
#   u'exp\xe9rience': 1,
#   u'faciliter': 1,
#   u'f\xeate': 1,
#   u'juriste': 1,
#   u'management': 4,
#   u'mettre': 1,
#   u'motivation': 1,
#   u'nombreux': 1,
#   u'opportunit\xe9': 1,
#   u'op\xe9ration': 2,
#   u'passionnant': 1,
#   u'professionnel': 1,
#   u'rendre': 1,
#   u'rigueur': 1,
#   u'toujours': 1,
#   u'travail': 1,
#   u'travailler': 1,
#   u'tr\xe8s': 1,
#   u'varier': 1,
#   u'veiller': 1,
#   u'voir': 1,
#   u'\xe9changer': 1,
#   u'\xeatre': 5},
#  u'flexible': {u'horaire': 1, u'secr\xe9tariat': 1},
#  u'dur': {u'connaissance': 1, u'pouvoir': 1, u'\xeatre': 1},
#  u'meeting': {u'semaine': 1},
#  u'exprimer': {u'\xe9cole': 1},
#  u'venir': {u'compliqu\xe9er': 1, u'part': 1, u'\xeatre': 1},
#  u'suivre': {u'agence': 1,
#   u'clients': 1,
#   u'tous': 1,
#   u'transmettre': 1,
#   u'vieux': 1},
#  u'direction': {u'3': 1, u'horaire': 1},
#  u'gentil': {u'pariba': 1, u'\xeatre': 1},
#  u'autonome': {u'libre': 1},
#  u'port\xe9e': {u't\xe2che': 1},
#  u'd\xe9tail': {u'apparenter': 1},
#  u'aussi': {u'agence': 1,
#   u'manquer': 1,
#   u'mieux': 1,
#   u'placement': 1,
#   u'plans': 1,
#   u'poste': 1,
#   u'provision': 1,
#   u'pr\xe9senter': 1,
#   u'\xe9chelle': 1,
#   u'\xeatre': 1},
#  u'opportunit\xe9': {u'agr\xe9able': 1,
#   u'an': 1,
#   u'charge': 1,
#   u'concerner': 1,
#   u'd\xe9veloppement': 1,
#   u'equivalent': 1,
#   u'fr\xe9quent': 1,
#   u'journ\xe9e': 1,
#   u'mail': 1,
#   u'nouvel': 1,
#   u'polyvalence': 1,
#   u'porte-feuille': 1,
#   u'pouvoir': 1,
#   u'rapide': 1,
#   u'responsable': 1,
#   u'r\xe9tention': 1,
#   u'sein': 1,
#   u'vue': 1},
#  u'r\xe9mun\xe9ration': {u'apprendre': 1},
#  u'distinguer': {u'groupe': 1},
#  u'd\xe9butant': {u'anglophone': 1},
#  u'humainement': {u'enrichissant': 1},
#  u'connaissance': {u'ensemble': 1,
#   u'entreprise': 1,
#   u'formation': 1,
#   u'permanent': 1,
#   u'\xeatre': 1},
#  u'aupr\xe8s': {u'postaux': 1},
#  u'exceptionnel': {u'contestation': 1},
#  u'\xe9lev\xe9er': {u'employ\xe9': 1},
#  u't\xf4t': {u'journ\xe9e': 1, u'permettre': 1},
#  u'former': {u'appel': 1,
#   u'entreprise': 1,
#   u'mat\xe9riel': 1,
#   u'v\xe9ritablement': 1},
#  u'g\xe9rance': {u'traitement': 1},
#  u'\xe9tablissement': {u'accorder': 1},
#  u'emploi': {u'cantine': 1, u'gestion': 1, u'tous': 1},
#  u'environnement': {u'agence': 1,
#   u'agr\xe9able': 2,
#   u'bilingue': 1,
#   u'cinq': 1,
#   u'classer': 1,
#   u'clients': 1,
#   u'confiance': 1,
#   u'lors': 1,
#   u'mettre': 1,
#   u'passer': 1,
#   u'peu': 1,
#   u'possibilit\xe9': 1,
#   u'rencontres': 1,
#   u'responsable': 1,
#   u'tre': 1,
#   u'tr\xe8s': 1},
#  u'jamais': {u'\xeatre': 1},
#  u't\xeate': {u'temps': 1, u'tier': 1},
#  u'rapidement': {u'\xeatre': 1},
#  u'appui': {u'd\xe9finie': 1},
#  u'talentueux': {u'\xeatre': 1},
#  u'erreur': {u'exercer': 1, u'gestion': 1},
#  u'ambitieux': {u'nombreux': 1},
#  u'confiance': {u'faire': 1, u'it': 1, u'permettre': 1, u'poste': 1},
#  u'priv\xe9er': {u'embauche': 1, u'vie': 1},
#  u'parfois': {u'clients': 1, u'client\xe8le': 1},
#  u'carri\xe8re': {u'client\xe8le': 1,
#   u'collaborateur': 1,
#   u'contact': 1,
#   u'donner': 1,
#   u'entreprise': 1,
#   u'forc\xe9ment': 1,
#   u'profil': 1},
#  u'd\xe9livrance': {u're\xe7uer': 1},
#  u'continuer': {u'apr\xe8s-midi': 1},
#  u'fa\xe7on': {u'13h': 1, u'\xe9voluon': 1},
#  u'riche': {u'100%': 1, u'p\xe9riode': 1},
#  u'am\xe9rique': {u'prononc\xe9er': 1},
#  u'externe': {u'perspectif': 1, u'\xe9quipe': 1},
#  u'pourquoi': {u'sentir': 1},
#  u'reconnaissance': {u'envoi': 1},
#  u'tant': {u'360': 1,
#   u'agr\xe9able': 1,
#   u'changement': 1,
#   u'disponible': 1,
#   u'mettre': 1,
#   u'pouvoir': 1,
#   u'\xeatre': 1},
#  u'observ\xe9er': {u's\xe9curisation': 1},
#  u'optimale': {u't\xe2che': 1},
#  u'prospectif': {u'revanche': 1},
#  u'mener': {u'redire': 1},
#  u'archif': {u'banque': 1},
#  u'respecter': {u'falloir': 1,
#   u'priser': 1,
#   u'proposition': 1,
#   u'\xe9quipe': 1,
#   u'\xeatre': 1},
#  u'pass\xe9er': {u'\xeatre': 1},
#  u'chiffre': {u'correct': 1, u'travail': 1},
#  u'salari\xe9': {u'financier': 1, u'nuire': 1, u'savoir': 1, u'\xeatre': 3},
#  u'd\xe9jeuner': {u'image': 1, u'journ\xe9e': 1, u'rangement': 1},
#  u'\xe9panouir': {u'vouloir': 1},
#  u'cergy': {u'succursale': 1},
#  u'amen\xe9re': {u'journ\xe9e': 1},
#  u'domaine': {u'exp\xe9rience': 1, u'professionnel': 1},
#  u'valoriser': {u'\xeatre': 1},
#  u'coll\xe8gue': {u'17h': 1,
#   u'ambiance': 1,
#   u'auxiliaire': 1,
#   u'besoin': 1,
#   u'collaborateur': 1,
#   u'connaissance': 1,
#   u'courrier': 1,
#   u'jeun': 1,
#   u'maintenir': 1,
#   u'management': 1,
#   u'plaire': 1,
#   u'r\xe9pondre': 1,
#   u'satisfaire': 1,
#   u'social': 1,
#   u'travail': 2,
#   u'varier': 1},
#  u'\xe9ch\xe9ance': {u'compte': 1},
#  u'fonds': {u'\xe9pargne': 1},
#  u'utile': {u'agr\xe9able': 1, u'donner': 1, u'formation': 1, u'valoriser': 1},
#  u'essentiel': {u'concertation': 1},
#  u'surcharge': {u'formation': 1},
#  u'cha\xeene': {u'maillon': 1},
#  u'rapprochement': {u'cr\xe9ation': 1},
#  u'consacrer': {u'n\xe9cessaire': 1},
#  u'r\xe9p\xe9titif': {u'dur\xe9e': 1},
#  u'parti': {u'disponible': 1},
#  u'r\xe9daction': {u'traitement': 1},
#  u'administration': {u'pouvoir': 1, u'service': 1},
#  u'h\xe9siter': {u'collaborateur': 1},
#  u'surveillance': {u'journ\xe9e': 1},
#  u'concerner': {u'carri\xe8re': 1, u'd\xe9cevoir': 1, u's\xe9curit\xe9': 1},
#  u'traiter': {u'accueillir': 1, u'bnp': 1, u'cr\xe9dit': 1},
#  u'grand': {u'employeur': 1,
#   u'employ\xe9': 1,
#   u'exp\xe9rience': 1,
#   u'organisation': 1,
#   u'poste': 1,
#   u'\xeatre': 1},
#  u'modification': {u'dossier': 1},
#  u'document': {u'actualisation': 1, u'informatique': 1, u'\xeatre': 1},
#  u'cinq': {u'fa\xe7on': 1},
#  u'aspecre': {u'travail': 1},
#  u'arriver': {u'9h': 1, u'groupe': 1, u'\xeatre': 1},
#  u'pr\xe9parer': {u'arriver': 1, u'collaborateur': 1},
#  u'relationnel': {u'aspect': 1, u'compte': 1},
#  u'devoir': {u'\xeatre': 2},
#  u'sortant': {u'amen\xe9re': 1},
#  u'social': {u'impersonnel': 1, u'point': 1, u'travail': 1},
#  u'm\xe9canique': {u'professionnel': 1},
#  u'plaisante': {u'ambiance': 1},
#  u'moment': {u'temps': 1},
#  u'diversit\xe9': {u'agr\xe9able': 1, u'perspective': 1},
#  u'glorifiant': {u'face': 1},
#  u'vieux': {u'entreprise': 1},
#  u'vivier': {u'offre': 1},
#  u'accompagnement': {u'cardif': 1, u'cr\xe9dit': 1},
#  u'moyen': {u'varier': 1},
#  u'parfait': {u'rythme': 1, u'\xbb': 1},
#  u'consid\xe9ration': {u'entreprise': 1, u'institution': 1},
#  u'pr\xe9c\xe9dent': {u'dossier': 1},
#  u'm\xe9tier': {u'd\xe9couvrir': 1,
#   u'figurer': 1,
#   u'niveau': 1,
#   u'pariba': 1,
#   u'permettre': 1,
#   u'p\xf4le': 1},
#  u'compte-rendu': {u'dossier': 1},
#  u'suppl\xe9mentaire': {u'permettre': 1},
#  u'finalement': {u'former': 1},
#  u'pr\xe9cis\xe9ment': {u'"': 1},
#  u'orienter': {u'contact': 1},
#  u'aise': {u'agence': 1, u'autre': 1, u'personnel': 1, u'travailler': 1},
#  u'r\xe9alis\xe9er': {u'laisser': 1},
#  u'charger': {u'client': 1, u'finir': 1},
#  u'certes': {u'objet': 1},
#  u'march\xe9': {u'evolution': 1, u'projet': 1},
#  u'faible': {u'innovation': 1, u'numero': 1},
#  u'concentrer': {u'falloir': 1},
#  u'juridiction': {u'r\xe9glementation': 1},
#  u'person': {u'agence': 1,
#   u'cardif': 1,
#   u'carri\xe8re': 1,
#   u'coursier': 1,
#   u'\xeatre': 1},
#  u'client': {u'8h': 1,
#   u'agr\xe9able': 1,
#   u'ambiance': 1,
#   u'autonomie': 1,
#   u'conformit\xe9': 1,
#   u'diff\xe9rent': 1,
#   u'esprit': 1,
#   u'g\xe9rer': 1,
#   u'humain': 1,
#   u'joignable': 1,
#   u'objectif': 1,
#   u'tarificatrice': 1,
#   u'toujours': 1,
#   u'tout': 1,
#   u'\xeatre': 2},
#  u'succursal': {u'employ\xe9': 1},
#  u'syst\xe8me': {u'horaire': 1},
#  u'appliqu\xe9er': {u'critiquable': 1},
#  u'position': {u'mod\xe8le': 1},
#  u'redistribution': {u'navette': 1, u'site': 1},
#  u'corporate': {u'coll\xe8gue': 1, u'gestion': 1},
#  u'choisir': {u'agence': 1},
#  u'g\xe2chent': {u'attitude': 1},
#  u'propos': {u'am\xe9liorer': 1, u'rien': 1},
#  u'coup': {u'toujours': 1},
#  u'g\xe9n\xe8re': {u'poste': 1},
#  u'gagner': {u'clients': 1},
#  u'manquer': {u'ouvertre': 1},
#  u'avancer': {u'particulier': 1, u'pouvoir': 1},
#  u'principalement': {u'all\xe9ger': 1,
#   u'bruyant': 1,
#   u'jeun': 1,
#   u'professionnalisation': 1},
#  u'taille': {u'bnp': 1},
#  u'renouvellement': {u'gestion': 1},
#  u't\xe9l\xe9phone': {u'demande': 1, u'locataire': 1, u'management': 1},
#  u'collectif': {u'administratif': 1,
#   u'collaborateur': 1,
#   u'\xe9l\xe9ment': 1,
#   u'\xeatre': 1},
#  u'proposer': {u'faire': 1, u'solution': 1, u'tr\xe8s': 1},
#  u'conseiller': {u'agence': 1,
#   u'importer': 1,
#   u'ouverture': 1,
#   u'sen': 1,
#   u'taches': 1,
#   u'tr\xe8s': 1,
#   u'viser': 1,
#   u'\xe9volution': 1},
#  u'anticiper': {u'proximit\xe9': 1},
#  u'r\xe9unir': {u'convivial': 1},
#  u'aspect': {u'arr\xeat': 1,
#   u'aspect': 1,
#   u'autre': 1,
#   u'coll\xe8gue': 1,
#   u'comp\xe9tence': 1,
#   u'comp\xe9tition': 1,
#   u'contact': 1,
#   u'demander': 1,
#   u'difficile': 1,
#   u'difficult\xe9': 1,
#   u'd\xe9veloppement': 2,
#   u'equilibre': 1,
#   u'imparti': 1,
#   u'objectif': 1,
#   u'parfait': 1,
#   u'parti': 1,
#   u'passer': 2,
#   u'poste': 1,
#   u'proc\xe9dure': 1,
#   u'pr\xeat': 1,
#   u'ressentir': 1,
#   u'satisfaire': 1,
#   u'structure': 1,
#   u'terminer': 1,
#   u'\xe9quipe': 1,
#   u'\xe9voluer': 1,
#   u'\xeatre': 2},
#  u'c\xf4t\xe9': {u'qualit\xe9': 1},
#  u'renouveler': {u'\xeatre': 1},
#  u'motiv\xe9': {u'implication': 1, u'jeun': 1},
#  u'progresser': {u'plein': 1, u'vite': 1},
#  u'convivial': {u'international': 1},
#  u'vari\xe9er': {u'autonomie': 1, u'taches': 1, u'tous': 1, u'\xe9quipe': 1},
#  u'g\xe9n\xe9r\xe9er': {u'rendre': 1},
#  u'esprit': {u'd\xe9velopper': 1,
#   u'environnement': 1,
#   u'performant': 1,
#   u'responsabilit\xe9': 1,
#   u'r\xe9f\xe9rence': 1,
#   u'souder': 1,
#   u'up': 1},
#  u'contribuer': {u'produire': 1},
#  u'source': {u'anticiper': 1, u'sein': 1},
#  u'difficile': {u'agr\xe9able': 1,
#   u'aider': 1,
#   u'bien': 1,
#   u'collaborateur': 1,
#   u'culture': 1,
#   u'diff\xe9rent': 1,
#   u'entenduer': 1,
#   u'entreprise': 1,
#   u'grandir': 1,
#   u'management': 1,
#   u'moins': 1,
#   u'permanent': 1,
#   u'r\xe9pondre': 1,
#   u'service': 1,
#   u'travail': 1,
#   u'travailler': 1,
#   u'vu': 1,
#   u'\xeatre': 2},
#  u'postaux': {u'redistribution': 1},
#  u'occuper': {u'aspect': 1,
#   u'attitrer': 1,
#   u'faire': 2,
#   u'gestion': 1,
#   u'principalement': 1,
#   u'pr\xe9parer': 1,
#   u'recenti': 1,
#   u'sein': 1},
#  u'4': {u'poste': 1, u'savoir': 1},
#  u'synth\xe8se': {u'n\xe9cessiter': 1},
#  u'cash': {u'clients': 1},
#  u'coll\xe9gue': {u'beaucoup': 1},
#  ...}
